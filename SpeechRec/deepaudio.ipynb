# %% [markdown]
# ### Import dependencies

# %%
#@title Install packages
# !pip install thop
# Out:
# Collecting thop
#   Downloading https://files.pythonhosted.org/packages/6c/8b/22ce44e1c71558161a8bd54471123cc796589c7ebbfc15a7e8932e522f83/thop-0.0.31.post2005241907-py3-none-any.whl
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from thop) (1.5.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->thop) (1.18.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->thop) (0.16.0)
# Installing collected packages: thop
# Successfully installed thop-0.0.31.post2005241907

# %%
#@title Import packages
# coding: utf-8
import shutil
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import librosa
import math
import random

from pathlib import Path

from torchvision.transforms import Compose
from tqdm import *

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data.sampler import WeightedRandomSampler
from thop import profile
from torchvision.models.quantization import shufflenet_v2_x0_5

# %% [markdown]
# ### Recover Google Speech Commands dataset

# %%
#@title Remove old data dir
# !rm -rf data/

# %%
#@title Download and unzip dataset
# !wget -nc http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz
# !mkdir -p data/audio
# !mkdir model
# !tar -xzvf speech_commands_v0.01.tar.gz -C data/audio/
# !rm speech_commands_v0.01.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# ./up/6f342826_nohash_0.wav
# ./up/e0a7c5a0_nohash_0.wav
# ./up/4d4e17f5_nohash_1.wav
# ./up/b0f24c9b_nohash_0.wav
# ./up/735845ab_nohash_2.wav
# ./up/53d5b86f_nohash_0.wav
# ./up/1a5b9ca4_nohash_1.wav
# ./up/23abe1c9_nohash_2.wav
# ./up/bdee441c_nohash_1.wav
# ./up/a1cff772_nohash_1.wav
# ./up/1ecfb537_nohash_3.wav
# ./up/37fc5d97_nohash_3.wav
# ./up/bd8412df_nohash_1.wav
# ./up/e53139ad_nohash_1.wav
# ./up/10ace7eb_nohash_3.wav
# ./up/30065f33_nohash_0.wav
# ./up/eefd26f3_nohash_0.wav
# ./up/c9b653a0_nohash_2.wav
# ./up/02746d24_nohash_0.wav
# ./up/e1469561_nohash_0.wav
# ./up/4bba14ce_nohash_0.wav
# ./up/b5d1e505_nohash_1.wav
# ./up/531a5b8a_nohash_1.wav
# ./up/0135f3f2_nohash_0.wav
# ./up/dbb40d24_nohash_4.wav
# ./up/e9287461_nohash_1.wav
# ./up/71e6ab20_nohash_0.wav
# ./up/ead2934a_nohash_1.wav
# ./up/f9af0887_nohash_0.wav
# ./up/ff63ab0b_nohash_0.wav
# ./up/f3d06008_nohash_0.wav
# ./up/918a2473_nohash_4.wav
# ./up/e54a0f16_nohash_0.wav
# ./up/cb8f8307_nohash_1.wav
# ./up/d197e3ae_nohash_3.wav
# ./up/53578f4e_nohash_0.wav
# ./up/234ab0fb_nohash_0.wav
# ./up/b00dff7e_nohash_1.wav
# ./up/8056e897_nohash_0.wav
# ./up/ad5aeec2_nohash_1.wav
# ./up/1365dd89_nohash_0.wav
# ./up/e4a2cf79_nohash_0.wav
# ./up/152491bc_nohash_0.wav
# ./up/18c54a68_nohash_0.wav
# ./up/9e46cfa1_nohash_1.wav
# ./up/7e6bd776_nohash_0.wav
# ./up/333784b7_nohash_0.wav
# ./up/f1b35ace_nohash_0.wav
# ./up/edc53350_nohash_0.wav
# ./up/229978fd_nohash_3.wav
# ./up/9e42ae25_nohash_0.wav
# ./up/28ce0c58_nohash_4.wav
# ./up/86fa2dcd_nohash_1.wav
# ./up/33f60c62_nohash_0.wav
# ./up/d103dd6e_nohash_1.wav
# ./up/712e4d58_nohash_3.wav
# ./up/982babaf_nohash_2.wav
# ./up/2fa39636_nohash_2.wav
# ./up/bf8d5617_nohash_0.wav
# ./up/364c0853_nohash_0.wav
# ./up/850e2222_nohash_1.wav
# ./up/b7a6f709_nohash_3.wav
# ./up/9a7c1f83_nohash_5.wav
# ./up/3ae5c04f_nohash_0.wav
# ./up/324210dd_nohash_2.wav
# ./up/c120e80e_nohash_2.wav
# ./up/69086eb0_nohash_0.wav
# ./up/dce05676_nohash_1.wav
# ./up/f9bdf10e_nohash_1.wav
# ./up/179a61b7_nohash_1.wav
# ./up/1c45ceb2_nohash_1.wav
# ./up/1df483c0_nohash_0.wav
# ./up/ba676390_nohash_0.wav
# ./up/65079685_nohash_1.wav
# ./up/aff582a1_nohash_4.wav
# ./up/512dc91a_nohash_1.wav
# ./up/6727b579_nohash_3.wav
# ./up/b65f6015_nohash_0.wav
# ./up/c22d3f18_nohash_4.wav
# ./up/15b0c947_nohash_0.wav
# ./up/9799379a_nohash_2.wav
# ./up/c5e3817f_nohash_0.wav
# ./up/da7689f1_nohash_0.wav
# ./up/5195f0ec_nohash_0.wav
# ./up/bbd0bbd0_nohash_2.wav
# ./up/f3210686_nohash_0.wav
# ./up/72320401_nohash_0.wav
# ./up/888a0c49_nohash_0.wav
# ./up/210f3aa9_nohash_0.wav
# ./up/da584bc0_nohash_2.wav
# ./up/34881b10_nohash_1.wav
# ./up/56f8a100_nohash_1.wav
# ./up/46a153d8_nohash_0.wav
# ./up/2be08ce4_nohash_0.wav
# ./up/96105282_nohash_1.wav
# ./up/03cf93b1_nohash_0.wav
# ./up/3b852f6f_nohash_4.wav
# ./up/77def3ee_nohash_0.wav
# ./up/a583c5b0_nohash_0.wav
# ./up/50a7d406_nohash_0.wav
# ./up/22aa3665_nohash_1.wav
# ./up/4f781a59_nohash_1.wav
# ./up/a8cf01bc_nohash_0.wav
# ./up/c53b335a_nohash_1.wav
# ./up/8e05039f_nohash_3.wav
# ./up/7846fd85_nohash_1.wav
# ./up/c120e80e_nohash_5.wav
# ./up/747e69fd_nohash_0.wav
# ./up/c86d4fd4_nohash_0.wav
# ./up/e805a617_nohash_0.wav
# ./up/3ab9ba07_nohash_0.wav
# ./up/abbfc3b4_nohash_0.wav
# ./up/520b2c17_nohash_0.wav
# ./up/44f68a83_nohash_2.wav
# ./up/c93d5e22_nohash_0.wav
# ./up/6cc28ce5_nohash_0.wav
# ./up/3c6e33df_nohash_0.wav
# ./up/0ab3b47d_nohash_0.wav
# ./up/8830e17f_nohash_1.wav
# ./up/2da58b32_nohash_1.wav
# ./up/a1cff772_nohash_0.wav
# ./up/726382d6_nohash_0.wav
# ./up/9886d8bf_nohash_1.wav
# ./up/2c7c33e8_nohash_1.wav
# ./up/0f250098_nohash_1.wav
# ./up/004ae714_nohash_0.wav
# ./up/c1d39ce8_nohash_2.wav
# ./up/3b8406c0_nohash_0.wav
# ./up/cd68e997_nohash_1.wav
# ./up/b8b8cb52_nohash_1.wav
# ./up/4c4d2526_nohash_0.wav
# ./up/de08912f_nohash_0.wav
# ./up/834f03fe_nohash_0.wav
# ./up/50033893_nohash_0.wav
# ./up/e7ea8b76_nohash_2.wav
# ./up/b59fe16d_nohash_0.wav
# ./up/11379f4d_nohash_0.wav
# ./up/37fc5d97_nohash_0.wav
# ./up/feb1d305_nohash_0.wav
# ./up/e0315cf6_nohash_3.wav
# ./up/7bae88ed_nohash_0.wav
# ./up/1e31353f_nohash_0.wav
# ./up/563aa4e6_nohash_1.wav
# ./up/9f22307d_nohash_0.wav
# ./up/7081436f_nohash_0.wav
# ./up/834f03fe_nohash_1.wav
# ./up/122c5aa7_nohash_2.wav
# ./up/cab100c9_nohash_3.wav
# ./up/48a9f771_nohash_0.wav
# ./up/24c9f572_nohash_0.wav
# ./up/37dca74f_nohash_0.wav
# ./up/29fb33da_nohash_1.wav
# ./up/1ecfb537_nohash_0.wav
# ./up/692a88e6_nohash_4.wav
# ./up/e7d0eb3f_nohash_1.wav
# ./up/2c6446f7_nohash_0.wav
# ./up/c634a189_nohash_0.wav
# ./up/c2e08f08_nohash_2.wav
# ./up/bbb2eb5b_nohash_0.wav
# ./up/9f869f70_nohash_1.wav
# ./up/1b63157b_nohash_0.wav
# ./up/611d2b50_nohash_3.wav
# ./up/b9515bf3_nohash_3.wav
# ./up/c2e08f08_nohash_1.wav
# ./up/2b715941_nohash_2.wav
# ./up/b11a05d2_nohash_0.wav
# ./up/617de221_nohash_4.wav
# ./up/611d2b50_nohash_0.wav
# ./up/c1e0e8e3_nohash_2.wav
# ./up/723efc4c_nohash_1.wav
# ./up/106a6183_nohash_2.wav
# ./up/de08912f_nohash_1.wav
# ./up/8625475c_nohash_1.wav
# ./up/c79159aa_nohash_2.wav
# ./up/35d1b6ee_nohash_1.wav
# ./up/573cdb8a_nohash_0.wav
# ./up/918a2473_nohash_3.wav
# ./up/692a88e6_nohash_0.wav
# ./up/06076b6b_nohash_1.wav
# ./up/f19d1738_nohash_0.wav
# ./up/3c8836dc_nohash_1.wav
# ./up/e5dadd24_nohash_2.wav
# ./up/264f471d_nohash_0.wav
# ./up/26e573a9_nohash_1.wav
# ./up/f06190c1_nohash_0.wav
# ./up/409c962a_nohash_0.wav
# ./up/edc53350_nohash_1.wav
# ./up/f953e1af_nohash_0.wav
# ./up/bd2db1a5_nohash_0.wav
# ./up/5e1b34a6_nohash_2.wav
# ./up/ae82c78c_nohash_0.wav
# ./up/b87bdb22_nohash_2.wav
# ./up/5fe4a278_nohash_0.wav
# ./up/b9515bf3_nohash_1.wav
# ./up/f92e49f3_nohash_3.wav
# ./up/763188c4_nohash_0.wav
# ./up/37fc5d97_nohash_2.wav
# ./up/479e64cc_nohash_0.wav
# ./up/c6ee87a7_nohash_4.wav
# ./up/e41e41f7_nohash_0.wav
# ./up/67c7fecb_nohash_0.wav
# ./up/6c968bd9_nohash_2.wav
# ./up/47565088_nohash_0.wav
# ./up/24632875_nohash_2.wav
# ./up/0f250098_nohash_0.wav
# ./up/c93d5e22_nohash_1.wav
# ./up/aeb99b1c_nohash_0.wav
# ./up/471a0925_nohash_2.wav
# ./up/3f170018_nohash_2.wav
# ./up/1ed557b9_nohash_0.wav
# ./up/5677ec77_nohash_1.wav
# ./up/093f65a1_nohash_0.wav
# ./up/6c968bd9_nohash_3.wav
# ./up/989a2213_nohash_0.wav
# ./up/e4a2cf79_nohash_2.wav
# ./up/587f3271_nohash_0.wav
# ./up/2aec99ec_nohash_0.wav
# ./up/9f22307d_nohash_1.wav
# ./up/dea820ce_nohash_1.wav
# ./up/37dca74f_nohash_3.wav
# ./up/9d050657_nohash_0.wav
# ./up/8b775397_nohash_0.wav
# ./up/2bdbe5f7_nohash_0.wav
# ./up/179a61b7_nohash_0.wav
# ./up/32efce64_nohash_0.wav
# ./up/05739450_nohash_2.wav
# ./up/cd7f8c1b_nohash_0.wav
# ./up/24ed94ab_nohash_0.wav
# ./up/b43c8f2f_nohash_1.wav
# ./up/d7529c0c_nohash_1.wav
# ./up/96c67073_nohash_0.wav
# ./up/dabd70c2_nohash_1.wav
# ./up/12529547_nohash_1.wav
# ./up/825f450d_nohash_1.wav
# ./up/8c7b691a_nohash_0.wav
# ./up/6846af18_nohash_0.wav
# ./up/e4a2cf79_nohash_3.wav
# ./up/5de3f6cc_nohash_3.wav
# ./up/c7b4049e_nohash_1.wav
# ./up/66a412a7_nohash_1.wav
# ./up/d069e6ff_nohash_0.wav
# ./up/8a56f36e_nohash_2.wav
# ./up/d9b8fab2_nohash_1.wav
# ./up/b5552931_nohash_0.wav
# ./up/7fd25f7c_nohash_2.wav
# ./up/34881b10_nohash_2.wav
# ./up/3d53244b_nohash_4.wav
# ./up/f00180d0_nohash_0.wav
# ./up/c8db14a8_nohash_0.wav
# ./up/6c0f6493_nohash_0.wav
# ./up/be91a00a_nohash_1.wav
# ./up/92b0a735_nohash_0.wav
# ./up/8e05039f_nohash_1.wav
# ./up/4f5c0b28_nohash_0.wav
# ./up/b4aa9fef_nohash_1.wav
# ./up/8a56f36e_nohash_3.wav
# ./up/21832144_nohash_1.wav
# ./up/77f185d3_nohash_0.wav
# ./up/86cb59b2_nohash_0.wav
# ./up/7211390b_nohash_1.wav
# ./up/66cbe2b3_nohash_0.wav
# ./up/b80d6c5e_nohash_0.wav
# ./up/cd7f8c1b_nohash_3.wav
# ./up/264f471d_nohash_2.wav
# ./up/402e2977_nohash_0.wav
# ./up/1816b768_nohash_0.wav
# ./up/d486fb84_nohash_1.wav
# ./up/1ffd513b_nohash_1.wav
# ./up/c38720cb_nohash_0.wav
# ./up/b49caed3_nohash_0.wav
# ./up/9712cce0_nohash_0.wav
# ./up/8b39e36f_nohash_1.wav
# ./up/a40c62f1_nohash_0.wav
# ./up/65079685_nohash_2.wav
# ./up/2ce7534c_nohash_0.wav
# ./up/b737ee80_nohash_1.wav
# ./up/c6a23ff5_nohash_2.wav
# ./up/7b2e879e_nohash_0.wav
# ./up/c5c60d8d_nohash_0.wav
# ./up/1d919a90_nohash_0.wav
# ./up/10ace7eb_nohash_1.wav
# ./up/3e549219_nohash_0.wav
# ./up/02e85b60_nohash_0.wav
# ./up/92a9c5e6_nohash_4.wav
# ./up/72aa7259_nohash_1.wav
# ./up/e5c48e53_nohash_0.wav
# ./up/70a00e98_nohash_0.wav
# ./up/a1a59b72_nohash_0.wav
# ./up/d8a5ace5_nohash_0.wav
# ./up/05739450_nohash_0.wav
# ./up/2d92f18b_nohash_0.wav
# ./up/9587481f_nohash_1.wav
# ./up/3b852f6f_nohash_3.wav
# ./up/1cec8d71_nohash_2.wav
# ./up/f297e878_nohash_0.wav
# ./up/f875f965_nohash_0.wav
# ./up/e72aa705_nohash_0.wav
# ./up/b97c9f77_nohash_3.wav
# ./up/ab71c9a7_nohash_0.wav
# ./up/0ac15fe9_nohash_0.wav
# ./up/2c7c33e8_nohash_0.wav
# ./up/cab100c9_nohash_0.wav
# ./up/a108341b_nohash_0.wav
# ./up/d750966e_nohash_0.wav
# ./up/c2df23b2_nohash_0.wav
# ./up/9d4bab4f_nohash_0.wav
# ./up/02e85b60_nohash_1.wav
# ./up/fb2f3242_nohash_0.wav
# ./up/28e47b1a_nohash_0.wav
# ./up/0137b3f4_nohash_3.wav
# ./up/531a5b8a_nohash_2.wav
# ./up/6d0ad764_nohash_0.wav
# ./up/f8f60f59_nohash_0.wav
# ./up/9a3f97f8_nohash_0.wav
# ./up/6c429c7b_nohash_0.wav
# ./up/b4aa9fef_nohash_3.wav
# ./up/1bb6ed89_nohash_0.wav
# ./up/24632875_nohash_0.wav
# ./up/db8a3397_nohash_0.wav
# ./up/e14a99a5_nohash_1.wav
# ./up/a4baac4e_nohash_0.wav
# ./up/834f03fe_nohash_4.wav
# ./up/a50a98d2_nohash_0.wav
# ./up/5fadb538_nohash_4.wav
# ./up/caa7feaf_nohash_0.wav
# ./up/66aa0f29_nohash_0.wav
# ./up/3402e488_nohash_1.wav
# ./up/10f2bb12_nohash_0.wav
# ./up/708b8d51_nohash_0.wav
# ./up/c1e0e8e3_nohash_0.wav
# ./up/060cd039_nohash_0.wav
# ./up/823353e5_nohash_1.wav
# ./up/17cc40ee_nohash_0.wav
# ./up/a6285644_nohash_0.wav
# ./up/c578beb0_nohash_0.wav
# ./up/90b94017_nohash_0.wav
# ./up/ef2a3cfb_nohash_0.wav
# ./up/4a0e2c16_nohash_0.wav
# ./up/f6617a86_nohash_0.wav
# ./up/9c59dd28_nohash_0.wav
# ./up/c0445658_nohash_4.wav
# ./up/686d030b_nohash_1.wav
# ./up/327289eb_nohash_1.wav
# ./up/7ff085e1_nohash_0.wav
# ./up/d1d3e64d_nohash_0.wav
# ./up/96a48d28_nohash_1.wav
# ./up/99b05bcf_nohash_1.wav
# ./up/dd6c6806_nohash_0.wav
# ./up/b959cd0c_nohash_1.wav
# ./up/9080f6d3_nohash_0.wav
# ./up/28ef2a01_nohash_0.wav
# ./up/49af4432_nohash_4.wav
# ./up/5fadb538_nohash_0.wav
# ./up/3d53244b_nohash_2.wav
# ./up/e6db3894_nohash_0.wav
# ./up/28e47b1a_nohash_2.wav
# ./up/3b852f6f_nohash_1.wav
# ./up/459345ea_nohash_0.wav
# ./up/88e90bc1_nohash_0.wav
# ./up/179a61b7_nohash_3.wav
# ./up/48a8a69d_nohash_0.wav
# ./up/83f9c4ab_nohash_0.wav
# ./up/a50a98d2_nohash_1.wav
# ./up/106a6183_nohash_1.wav
# ./up/e2362167_nohash_1.wav
# ./up/541e4079_nohash_1.wav
# ./up/953fe1ad_nohash_0.wav
# ./up/e9287461_nohash_0.wav
# ./up/9a8d8d34_nohash_2.wav
# ./up/92037d73_nohash_0.wav
# ./up/b5d1e505_nohash_2.wav
# ./up/cfde27ba_nohash_1.wav
# ./up/13199b79_nohash_0.wav
# ./up/652b3da7_nohash_1.wav
# ./up/e82914c0_nohash_0.wav
# ./up/0397ecda_nohash_0.wav
# ./up/46a153d8_nohash_2.wav
# ./up/27b03931_nohash_0.wav
# ./up/016e2c6d_nohash_0.wav
# ./up/e8e960fd_nohash_1.wav
# ./up/c2e08f08_nohash_0.wav
# ./up/ec201020_nohash_2.wav
# ./up/3dfd6c23_nohash_0.wav
# ./up/512dc91a_nohash_0.wav
# ./up/e53139ad_nohash_4.wav
# ./up/b93528e3_nohash_0.wav
# ./up/9ff1b8b6_nohash_0.wav
# ./up/363c6bad_nohash_0.wav
# ./up/c79159aa_nohash_3.wav
# ./up/c7aaad67_nohash_1.wav
# ./up/3bfd30e6_nohash_0.wav
# ./up/f953e1af_nohash_4.wav
# ./up/5e3dde6b_nohash_2.wav
# ./up/b087aa0e_nohash_0.wav
# ./up/39a12648_nohash_4.wav
# ./up/57376a4c_nohash_1.wav
# ./up/106a6183_nohash_3.wav
# ./up/bd061bef_nohash_1.wav
# ./up/aff582a1_nohash_3.wav
# ./up/39ec87ac_nohash_0.wav
# ./up/0d53e045_nohash_1.wav
# ./up/650daf8e_nohash_0.wav
# ./up/0ff728b5_nohash_0.wav
# ./up/763188c4_nohash_2.wav
# ./up/cdbd6969_nohash_1.wav
# ./up/ffbb695d_nohash_0.wav
# ./up/39a12648_nohash_1.wav
# ./up/97f4c236_nohash_2.wav
# ./up/d2eae23d_nohash_0.wav
# ./up/151bfb79_nohash_0.wav
# ./up/e5dadd24_nohash_1.wav
# ./up/146d97db_nohash_1.wav
# ./up/d0f7bef5_nohash_1.wav
# ./up/493392c6_nohash_0.wav
# ./up/11099149_nohash_0.wav
# ./up/c842b5e4_nohash_0.wav
# ./up/d98f6043_nohash_0.wav
# ./up/190821dc_nohash_3.wav
# ./up/6e41a77e_nohash_1.wav
# ./up/1c3f50ad_nohash_0.wav
# ./up/39ec87ac_nohash_1.wav
# ./up/76b58705_nohash_0.wav
# ./up/1ecfb537_nohash_4.wav
# ./up/571c044e_nohash_1.wav
# ./up/a1cff772_nohash_4.wav
# ./up/5c8af87a_nohash_4.wav
# ./up/2d3c8dcb_nohash_0.wav
# ./up/422f8cf1_nohash_1.wav
# ./up/dabf67d9_nohash_0.wav
# ./up/b97c9f77_nohash_4.wav
# ./up/7d8babdb_nohash_0.wav
# ./up/353b4d33_nohash_1.wav
# ./up/64574a99_nohash_0.wav
# ./up/9dc1889e_nohash_0.wav
# ./up/28460a60_nohash_0.wav
# ./up/67fcdb05_nohash_0.wav
# ./up/ef2a3cfb_nohash_1.wav
# ./up/83957201_nohash_1.wav
# ./up/7cf14c54_nohash_0.wav
# ./up/b7a6f709_nohash_2.wav
# ./up/eb0676ec_nohash_0.wav
# ./up/982babaf_nohash_1.wav
# ./up/6c9223bd_nohash_0.wav
# ./up/70a00e98_nohash_3.wav
# ./up/9e46cfa1_nohash_2.wav
# ./up/c93d5e22_nohash_2.wav
# ./up/c392e01d_nohash_0.wav
# ./up/8dd24423_nohash_0.wav
# ./up/a5b24175_nohash_0.wav
# ./up/9aa21fa9_nohash_3.wav
# ./up/0c2d2ffa_nohash_1.wav
# ./up/2bd2cad5_nohash_0.wav
# ./up/190821dc_nohash_4.wav
# ./up/626e323f_nohash_0.wav
# ./up/ce49cb60_nohash_0.wav
# ./up/3e3b65eb_nohash_0.wav
# ./up/1daa5ada_nohash_0.wav
# ./up/742d6431_nohash_3.wav
# ./up/bdee441c_nohash_3.wav
# ./up/b7a0754f_nohash_1.wav
# ./up/f92e49f3_nohash_0.wav
# ./up/1ba20be2_nohash_0.wav
# ./up/6cb6eee7_nohash_2.wav
# ./up/be7a5b2d_nohash_4.wav
# ./up/c948d727_nohash_3.wav
# ./up/659b7fae_nohash_1.wav
# ./up/a8688b67_nohash_0.wav
# ./up/f6af2457_nohash_1.wav
# ./up/e8b6f6fe_nohash_0.wav
# ./up/611d2b50_nohash_2.wav
# ./up/e0ff1e9c_nohash_0.wav
# ./up/a6d586b7_nohash_2.wav
# ./up/16d41d07_nohash_0.wav
# ./up/6b81fead_nohash_0.wav
# ./up/4a1e736b_nohash_3.wav
# ./up/22aa3665_nohash_2.wav
# ./up/70a00e98_nohash_1.wav
# ./up/c4500713_nohash_0.wav
# ./up/3ff840aa_nohash_0.wav
# ./up/ffd2ba2f_nohash_0.wav
# ./up/28e47b1a_nohash_1.wav
# ./up/ead2934a_nohash_0.wav
# ./up/cc2f1a85_nohash_0.wav
# ./up/c44d2a58_nohash_0.wav
# ./up/99fad6a0_nohash_2.wav
# ./up/df6bd83f_nohash_0.wav
# ./up/bfbd0e6b_nohash_0.wav
# ./up/070b49af_nohash_1.wav
# ./up/7318280c_nohash_0.wav
# ./up/d933bf5e_nohash_0.wav
# ./up/8281a2a8_nohash_3.wav
# ./up/3ff840aa_nohash_1.wav
# ./up/e3411931_nohash_1.wav
# ./up/ea356919_nohash_1.wav
# ./up/b4aa9fef_nohash_0.wav
# ./up/9ff2d2f4_nohash_2.wav
# ./up/65f2531f_nohash_0.wav
# ./up/e7117d00_nohash_0.wav
# ./up/bdee441c_nohash_4.wav
# ./up/4290ca61_nohash_0.wav
# ./up/833a0279_nohash_0.wav
# ./up/46a153d8_nohash_4.wav
# ./up/cee22275_nohash_1.wav
# ./up/d486fb84_nohash_0.wav
# ./up/e8c3c5ca_nohash_0.wav
# ./up/7d5f87c8_nohash_1.wav
# ./up/7dc95912_nohash_0.wav
# ./up/6a2fb9a5_nohash_0.wav
# ./up/6c429c7b_nohash_3.wav
# ./up/3bc21161_nohash_3.wav
# ./up/1aed7c6d_nohash_0.wav
# ./up/82c6d220_nohash_0.wav
# ./up/f59d0771_nohash_0.wav
# ./up/6c429c7b_nohash_4.wav
# ./up/3c8836dc_nohash_0.wav
# ./up/4a294341_nohash_1.wav
# ./up/67c7fecb_nohash_1.wav
# ./up/1b459024_nohash_0.wav
# ./up/9a69672b_nohash_0.wav
# ./up/4c841771_nohash_2.wav
# ./up/c1e0e8e3_nohash_4.wav
# ./up/2d92f18b_nohash_1.wav
# ./up/3f2b358d_nohash_0.wav
# ./up/80b8eab4_nohash_2.wav
# ./up/c661be6e_nohash_0.wav
# ./up/c0c701f1_nohash_0.wav
# ./up/c948d727_nohash_0.wav
# ./up/b83c1acf_nohash_3.wav
# ./up/1b835b87_nohash_1.wav
# ./up/e649aa92_nohash_0.wav
# ./up/1dce06e8_nohash_1.wav
# ./up/d103dd6e_nohash_0.wav
# ./up/e54a0f16_nohash_2.wav
# ./up/caf9fceb_nohash_1.wav
# ./up/3eb8764c_nohash_0.wav
# ./up/8b775397_nohash_1.wav
# ./up/44bc77f7_nohash_0.wav
# ./up/74fc51e5_nohash_0.wav
# ./up/19f9c115_nohash_0.wav
# ./up/c1e0e8e3_nohash_3.wav
# ./up/86648261_nohash_0.wav
# ./up/73f0c1f7_nohash_0.wav
# ./up/8012c69d_nohash_4.wav
# ./up/7ca023e2_nohash_0.wav
# ./up/44715c1c_nohash_1.wav
# ./up/745a8e32_nohash_2.wav
# ./up/f5733968_nohash_0.wav
# ./up/3bfd30e6_nohash_4.wav
# ./up/190821dc_nohash_2.wav
# ./up/4f086393_nohash_0.wav
# ./up/6f342826_nohash_1.wav
# ./up/ca4eeab0_nohash_0.wav
# ./up/3c1e12cf_nohash_0.wav
# ./up/122c5aa7_nohash_4.wav
# ./up/6f3458b3_nohash_0.wav
# ./up/f4386675_nohash_0.wav
# ./up/1338a799_nohash_0.wav
# ./up/a0a8d759_nohash_0.wav
# ./up/7211390b_nohash_3.wav
# ./up/39a12648_nohash_2.wav
# ./up/7f74626f_nohash_1.wav
# ./up/c7aa72e6_nohash_0.wav
# ./up/d933bf5e_nohash_1.wav
# ./up/bbd0bbd0_nohash_4.wav
# ./up/918a2473_nohash_2.wav
# ./up/8a0457c9_nohash_0.wav
# ./up/dbb7723a_nohash_0.wav
# ./up/7e783e3f_nohash_0.wav
# ./up/36de13e1_nohash_0.wav
# ./up/964e8cfd_nohash_2.wav
# ./up/50d1c8e3_nohash_0.wav
# ./up/1e31353f_nohash_1.wav
# ./up/69f609ec_nohash_0.wav
# ./up/3e549219_nohash_1.wav
# ./up/2da58b32_nohash_4.wav
# ./up/ad5aeec2_nohash_0.wav
# ./up/f21893dc_nohash_0.wav
# ./up/fd395b74_nohash_3.wav
# ./up/3f2b358d_nohash_2.wav
# ./up/c71e3acc_nohash_0.wav
# ./up/24befdb3_nohash_3.wav
# ./up/96a48d28_nohash_2.wav
# ./up/c948d727_nohash_4.wav
# ./up/b487da60_nohash_0.wav
# ./up/34805883_nohash_1.wav
# ./up/69953f48_nohash_0.wav
# ./up/f33660af_nohash_1.wav
# ./up/d33df435_nohash_0.wav
# ./up/6c0f6493_nohash_2.wav
# ./up/c0fb6812_nohash_0.wav
# ./up/a6d586b7_nohash_1.wav
# ./up/f0ebef1b_nohash_0.wav
# ./up/71f6fed7_nohash_0.wav
# ./up/ced835d3_nohash_1.wav
# ./up/27b03931_nohash_1.wav
# ./up/e91d173e_nohash_0.wav
# ./up/422f8cf1_nohash_0.wav
# ./up/2aa787cf_nohash_0.wav
# ./up/692a88e6_nohash_3.wav
# ./up/274c008f_nohash_1.wav
# ./up/659b7fae_nohash_0.wav
# ./up/39999a0f_nohash_1.wav
# ./up/7799c9cd_nohash_1.wav
# ./up/8134f43f_nohash_2.wav
# ./up/b72e58c9_nohash_0.wav
# ./up/173ce2be_nohash_1.wav
# ./up/ad6a46f1_nohash_0.wav
# ./up/ecd4fd45_nohash_0.wav
# ./up/66774579_nohash_0.wav
# ./up/48e8b82a_nohash_0.wav
# ./up/f428ca69_nohash_1.wav
# ./up/0a7c2a8d_nohash_0.wav
# ./up/aa109cfb_nohash_1.wav
# ./up/8a56f36e_nohash_0.wav
# ./up/caedb73a_nohash_1.wav
# ./up/5aac2efa_nohash_0.wav
# ./up/50ed8a7b_nohash_0.wav
# ./up/7e2d5caf_nohash_0.wav
# ./up/4a294341_nohash_2.wav
# ./up/24befdb3_nohash_2.wav
# ./up/af30314d_nohash_1.wav
# ./up/f953e1af_nohash_3.wav
# ./up/c68cf200_nohash_0.wav
# ./up/5c8af87a_nohash_0.wav
# ./up/8e884ec4_nohash_0.wav
# ./up/44c201dd_nohash_0.wav
# ./up/6c968bd9_nohash_1.wav
# ./up/b87bdb22_nohash_3.wav
# ./up/ffd2ba2f_nohash_1.wav
# ./up/964e8cfd_nohash_3.wav
# ./up/b9f46737_nohash_5.wav
# ./up/c392e01d_nohash_1.wav
# ./up/59b98a22_nohash_1.wav
# ./up/3006c271_nohash_0.wav
# ./up/21cbe292_nohash_0.wav
# ./up/079dfce3_nohash_0.wav
# ./up/fac7deca_nohash_1.wav
# ./up/b52bd596_nohash_0.wav
# ./up/aff582a1_nohash_0.wav
# ./up/21832144_nohash_4.wav
# ./up/fe5c4a7a_nohash_0.wav
# ./up/126403d4_nohash_0.wav
# ./up/c120e80e_nohash_1.wav
# ./up/179a61b7_nohash_2.wav
# ./up/c1d39ce8_nohash_4.wav
# ./up/01bb6a2a_nohash_4.wav
# ./up/57376a4c_nohash_0.wav
# ./up/be7a5b2d_nohash_1.wav
# ./up/49af4432_nohash_2.wav
# ./up/c37a72d3_nohash_0.wav
# ./up/61a0d340_nohash_2.wav
# ./up/98582fee_nohash_0.wav
# ./up/46114b4e_nohash_1.wav
# ./up/953fe1ad_nohash_1.wav
# ./up/d1a17cbe_nohash_0.wav
# ./up/3c8836dc_nohash_2.wav
# ./up/8d4cdc60_nohash_1.wav
# ./up/48463cbc_nohash_1.wav
# ./up/b1426003_nohash_0.wav
# ./up/c22d3f18_nohash_2.wav
# ./up/6c6aa323_nohash_0.wav
# ./up/c1d39ce8_nohash_3.wav
# ./up/c6ee87a7_nohash_2.wav
# ./up/493392c6_nohash_1.wav
# ./up/40115b19_nohash_2.wav
# ./up/553f1a79_nohash_2.wav
# ./up/0d2bcf9d_nohash_0.wav
# ./up/8830e17f_nohash_0.wav
# ./up/333784b7_nohash_3.wav
# ./up/9a7c1f83_nohash_3.wav
# ./up/cb2929ce_nohash_6.wav
# ./up/31270cb2_nohash_0.wav
# ./up/eb3f7d82_nohash_2.wav
# ./up/dff327c5_nohash_2.wav
# ./up/e41a903b_nohash_4.wav
# ./up/4d4e17f5_nohash_0.wav
# ./up/be7a5b2d_nohash_3.wav
# ./up/da2c5f1b_nohash_3.wav
# ./up/9f4098cb_nohash_0.wav
# ./up/94de6a6a_nohash_2.wav
# ./up/18a1aab9_nohash_4.wav
# ./up/210f3aa9_nohash_1.wav
# ./up/3c8dc702_nohash_0.wav
# ./up/2796ac50_nohash_0.wav
# ./up/e5afa9b0_nohash_1.wav
# ./up/435f9f9e_nohash_0.wav
# ./up/aac5b7c1_nohash_0.wav
# ./up/29fb33da_nohash_2.wav
# ./up/4a1e736b_nohash_0.wav
# ./up/96ab6565_nohash_4.wav
# ./up/37e8db82_nohash_0.wav
# ./up/cd7f8c1b_nohash_4.wav
# ./up/23abe1c9_nohash_1.wav
# ./up/d0f7bef5_nohash_0.wav
# ./up/070b49af_nohash_0.wav
# ./up/c1e0e8e3_nohash_1.wav
# ./up/840eab5a_nohash_0.wav
# ./up/cd8b1781_nohash_0.wav
# ./up/7c2a3fa4_nohash_0.wav
# ./up/ab5b211a_nohash_0.wav
# ./up/8830e17f_nohash_2.wav
# ./up/d197e3ae_nohash_0.wav
# ./up/82e7204d_nohash_2.wav
# ./up/cc6ee39b_nohash_3.wav
# ./up/2fa39636_nohash_1.wav
# ./up/179a61b7_nohash_4.wav
# ./up/531a5b8a_nohash_0.wav
# ./up/fbdc07bb_nohash_0.wav
# ./up/569455ff_nohash_1.wav
# ./up/553f1a79_nohash_1.wav
# ./up/20d3f11f_nohash_0.wav
# ./up/5de3f6cc_nohash_1.wav
# ./up/a108341b_nohash_1.wav
# ./up/db4cf12f_nohash_0.wav
# ./up/f192e6b4_nohash_0.wav
# ./up/da2c5f1b_nohash_2.wav
# ./up/ba770f9b_nohash_0.wav
# ./up/9a69672b_nohash_4.wav
# ./up/cc71bada_nohash_0.wav
# ./up/da15e796_nohash_1.wav
# ./up/0c2d2ffa_nohash_0.wav
# ./up/90804775_nohash_0.wav
# ./up/1a892463_nohash_0.wav
# ./up/099d52ad_nohash_1.wav
# ./up/37dca74f_nohash_4.wav
# ./up/c634a189_nohash_1.wav
# ./up/2e73212b_nohash_0.wav
# ./up/5677ec77_nohash_0.wav
# ./up/d31d8dd7_nohash_0.wav
# ./up/8830e17f_nohash_3.wav
# ./up/7846fd85_nohash_2.wav
# ./up/cb2929ce_nohash_3.wav
# ./up/e95c70e2_nohash_0.wav
# ./up/617de221_nohash_0.wav
# ./up/4f2be90f_nohash_0.wav
# ./up/53eb0a88_nohash_0.wav
# ./up/d9462202_nohash_1.wav
# ./up/34881b10_nohash_0.wav
# ./up/13d7b8c9_nohash_0.wav
# ./up/eee5e541_nohash_1.wav
# ./up/1ecfb537_nohash_1.wav
# ./up/c7aaad67_nohash_2.wav
# ./up/520e8c0e_nohash_0.wav
# ./up/52e228e9_nohash_0.wav
# ./up/471a0925_nohash_1.wav
# ./up/1c45ceb2_nohash_0.wav
# ./up/3d9200b9_nohash_0.wav
# ./up/39a6b995_nohash_0.wav
# ./up/0474c92a_nohash_0.wav
# ./up/988e2f9a_nohash_1.wav
# ./up/43fc47a7_nohash_2.wav
# ./up/653a48f5_nohash_0.wav
# ./up/324210dd_nohash_0.wav
# ./up/56eb74ae_nohash_2.wav
# ./up/b9f46737_nohash_2.wav
# ./up/9e2ce5e3_nohash_0.wav
# ./up/3ff840aa_nohash_2.wav
# ./up/daf230ac_nohash_0.wav
# ./up/51055bda_nohash_3.wav
# ./up/bbd0bbd0_nohash_3.wav
# ./up/5e1b34a6_nohash_1.wav
# ./up/19e98e89_nohash_0.wav
# ./up/5c39594f_nohash_4.wav
# ./up/c22d3f18_nohash_1.wav
# ./up/97101ef3_nohash_0.wav
# ./up/38d78313_nohash_2.wav
# ./up/0137b3f4_nohash_4.wav
# ./up/36050ef3_nohash_1.wav
# ./up/363c6bad_nohash_1.wav
# ./up/39999a0f_nohash_0.wav
# ./up/3b7f817e_nohash_0.wav
# ./up/5e3dde6b_nohash_3.wav
# ./up/1eddce1d_nohash_0.wav
# ./up/ea356919_nohash_2.wav
# ./up/745a8e32_nohash_0.wav
# ./up/cd85758f_nohash_1.wav
# ./up/840c366d_nohash_2.wav
# ./up/e71b4ce6_nohash_1.wav
# ./up/0f3f64d5_nohash_2.wav
# ./up/686d030b_nohash_2.wav
# ./up/8830e17f_nohash_4.wav
# ./up/3c8dc702_nohash_1.wav
# ./up/8a56f36e_nohash_1.wav
# ./up/56eab10e_nohash_0.wav
# ./up/10ace7eb_nohash_4.wav
# ./up/bca56796_nohash_0.wav
# ./up/d8ee4734_nohash_0.wav
# ./up/7f17667c_nohash_0.wav
# ./up/1ffd513b_nohash_0.wav
# ./up/80fe1dc7_nohash_0.wav
# ./up/b5552931_nohash_1.wav
# ./up/facd97c0_nohash_0.wav
# ./up/c6a23ff5_nohash_0.wav
# ./up/1890e5c3_nohash_3.wav
# ./up/eb76bc68_nohash_1.wav
# ./up/c24d96eb_nohash_0.wav
# ./up/86b89661_nohash_0.wav
# ./up/7d8babdb_nohash_1.wav
# ./up/42beb5eb_nohash_0.wav
# ./up/cc6ee39b_nohash_1.wav
# ./up/a583c5b0_nohash_1.wav
# ./up/22aa3665_nohash_0.wav
# ./up/66041c69_nohash_1.wav
# ./up/e3411931_nohash_0.wav
# ./up/f3210686_nohash_1.wav
# ./up/dd086776_nohash_0.wav
# ./up/3bfd30e6_nohash_2.wav
# ./up/f9f9751d_nohash_0.wav
# ./up/402e2977_nohash_1.wav
# ./up/ae927455_nohash_0.wav
# ./up/f4c77b26_nohash_0.wav
# ./up/bd061bef_nohash_0.wav
# ./up/dca2797e_nohash_2.wav
# ./up/10ace7eb_nohash_2.wav
# ./up/9db2bfe9_nohash_1.wav
# ./up/686d030b_nohash_3.wav
# ./up/019fa366_nohash_0.wav
# ./up/ced835d3_nohash_4.wav
# ./up/cb8f8307_nohash_3.wav
# ./up/7de97453_nohash_0.wav
# ./up/b87bdb22_nohash_4.wav
# ./up/d7529c0c_nohash_0.wav
# ./up/c661be6e_nohash_1.wav
# ./up/9b5815cd_nohash_1.wav
# ./up/d94eb94f_nohash_1.wav
# ./up/4a1e736b_nohash_4.wav
# ./up/014f9f65_nohash_0.wav
# ./up/a42a88ff_nohash_0.wav
# ./up/cd85758f_nohash_3.wav
# ./up/dcc012ec_nohash_2.wav
# ./up/dff327c5_nohash_0.wav
# ./up/118261a9_nohash_0.wav
# ./up/569455ff_nohash_0.wav
# ./up/91cdef62_nohash_0.wav
# ./up/7c1d8533_nohash_1.wav
# ./up/3bc21161_nohash_1.wav
# ./up/d3badc9a_nohash_2.wav
# ./up/c634a189_nohash_3.wav
# ./up/c79159aa_nohash_0.wav
# ./up/28ed6bc9_nohash_1.wav
# ./up/24befdb3_nohash_0.wav
# ./up/f34e6f44_nohash_0.wav
# ./up/b7669804_nohash_0.wav
# ./up/96a48d28_nohash_3.wav
# ./up/f19c1390_nohash_0.wav
# ./up/7192fddc_nohash_1.wav
# ./up/8281a2a8_nohash_4.wav
# ./up/8910e5ef_nohash_0.wav
# ./up/e652590d_nohash_0.wav
# ./up/78030270_nohash_0.wav
# ./up/56eb74ae_nohash_4.wav
# ./up/229978fd_nohash_0.wav
# ./up/dea820ce_nohash_2.wav
# ./up/4f8ef132_nohash_1.wav
# ./up/b97c9f77_nohash_2.wav
# ./up/2e0d80f7_nohash_0.wav
# ./up/c103a2d5_nohash_1.wav
# ./up/2aa787cf_nohash_1.wav
# ./up/3fdafe25_nohash_0.wav
# ./up/e102119e_nohash_0.wav
# ./up/da584bc0_nohash_3.wav
# ./up/db72a474_nohash_3.wav
# ./up/8ec6dab6_nohash_0.wav
# ./up/bc065a17_nohash_0.wav
# ./up/b5aacf2c_nohash_1.wav
# ./up/6fca237d_nohash_0.wav
# ./up/18a1aab9_nohash_0.wav
# ./up/3bc21161_nohash_4.wav
# ./up/fb24c826_nohash_0.wav
# ./up/d8ee4734_nohash_1.wav
# ./up/da76aa58_nohash_1.wav
# ./up/742d6431_nohash_2.wav
# ./up/850e2222_nohash_0.wav
# ./up/e53139ad_nohash_2.wav
# ./up/99a9b015_nohash_0.wav
# ./up/7ea032f3_nohash_2.wav
# ./up/079dfce3_nohash_1.wav
# ./up/32a19ecf_nohash_0.wav
# ./up/b97c9f77_nohash_0.wav
# ./up/c948d727_nohash_1.wav
# ./up/25132942_nohash_0.wav
# ./up/d5ca80c6_nohash_0.wav
# ./up/fd32732a_nohash_0.wav
# ./up/cc6ee39b_nohash_2.wav
# ./up/f8ad3941_nohash_0.wav
# ./up/25040e85_nohash_0.wav
# ./up/01d22d03_nohash_0.wav
# ./testing_list.txt
# ./on/
# ./on/1b88bf70_nohash_0.wav
# ./on/750e3e75_nohash_0.wav
# ./on/3852fca2_nohash_0.wav
# ./on/5ac04a92_nohash_0.wav
# ./on/778a4a01_nohash_0.wav
# ./on/61e50f62_nohash_0.wav
# ./on/e77d88fc_nohash_1.wav
# ./on/17c94b23_nohash_0.wav
# ./on/037c445a_nohash_1.wav
# ./on/11321027_nohash_0.wav
# ./on/e55a2b20_nohash_1.wav
# ./on/b97c9f77_nohash_1.wav
# ./on/09bcdc9d_nohash_0.wav
# ./on/cae62f38_nohash_1.wav
# ./on/1942abd7_nohash_0.wav
# ./on/b8872c20_nohash_1.wav
# ./on/48bdc11c_nohash_0.wav
# ./on/cb2929ce_nohash_4.wav
# ./on/01b4757a_nohash_0.wav
# ./on/ea1f888c_nohash_0.wav
# ./on/88120683_nohash_0.wav
# ./on/f9ebdba0_nohash_0.wav
# ./on/1ecfb537_nohash_2.wav
# ./on/6a27a9bf_nohash_0.wav
# ./on/7ff4fc72_nohash_0.wav
# ./on/50f55535_nohash_0.wav
# ./on/58df33b5_nohash_0.wav
# ./on/cd7f8c1b_nohash_2.wav
# ./on/7e4fa1d8_nohash_0.wav
# ./on/6f5b4d3d_nohash_2.wav
# ./on/b8872c20_nohash_0.wav
# ./on/eb3f7d82_nohash_1.wav
# ./on/c120e80e_nohash_6.wav
# ./on/7fc74fbe_nohash_1.wav
# ./on/4422e51d_nohash_0.wav
# ./on/6ac35824_nohash_0.wav
# ./on/dca6b373_nohash_1.wav
# ./on/652b3da7_nohash_0.wav
# ./on/a3502f15_nohash_0.wav
# ./on/735845ab_nohash_3.wav
# ./on/1fd85ee4_nohash_0.wav
# ./on/4def68db_nohash_2.wav
# ./on/5af0ca83_nohash_0.wav
# ./on/95218ce8_nohash_0.wav
# ./on/8c4854bc_nohash_0.wav
# ./on/96d5276f_nohash_2.wav
# ./on/c1d39ce8_nohash_5.wav
# ./on/d0faf7e4_nohash_4.wav
# ./on/782c1305_nohash_1.wav
# ./on/325a0c39_nohash_0.wav
# ./on/2643992f_nohash_0.wav
# ./on/735845ab_nohash_0.wav
# ./on/fc2411fe_nohash_0.wav
# ./on/68dd409e_nohash_0.wav
# ./on/a13e0a74_nohash_0.wav
# ./on/9aa21fa9_nohash_2.wav
# ./on/471a0925_nohash_4.wav
# ./on/f19c1390_nohash_4.wav
# ./on/3a789a0d_nohash_0.wav
# ./on/81a345a3_nohash_0.wav
# ./on/44dad20e_nohash_2.wav
# ./on/3565ca83_nohash_2.wav
# ./on/a8e25ebb_nohash_1.wav
# ./on/6982fc2a_nohash_2.wav
# ./on/ad1429cf_nohash_0.wav
# ./on/605ed0ff_nohash_1.wav
# ./on/e55a2b20_nohash_0.wav
# ./on/712e4d58_nohash_4.wav
# ./on/1f653d27_nohash_1.wav
# ./on/57cb3575_nohash_1.wav
# ./on/ffa76c4a_nohash_0.wav
# ./on/56eb74ae_nohash_0.wav
# ./on/e62056e2_nohash_0.wav
# ./on/c245d3d7_nohash_1.wav
# ./on/b9f46737_nohash_4.wav
# ./on/31e686d2_nohash_0.wav
# ./on/229978fd_nohash_1.wav
# ./on/dbb40d24_nohash_1.wav
# ./on/c103a2d5_nohash_0.wav
# ./on/1b4c9b89_nohash_0.wav
# ./on/5efb758c_nohash_1.wav
# ./on/0474c92a_nohash_1.wav
# ./on/ec74a8a5_nohash_0.wav
# ./on/01bb6a2a_nohash_2.wav
# ./on/bd11c654_nohash_0.wav
# ./on/5ba724a7_nohash_0.wav
# ./on/1b755c65_nohash_0.wav
# ./on/c6ee87a7_nohash_3.wav
# ./on/28e47b1a_nohash_3.wav
# ./on/b87bdb22_nohash_0.wav
# ./on/81dc4a94_nohash_0.wav
# ./on/a9b574b3_nohash_0.wav
# ./on/106a6183_nohash_0.wav
# ./on/9735764a_nohash_0.wav
# ./on/ee4a907f_nohash_0.wav
# ./on/ce9410da_nohash_0.wav
# ./on/7117fb6d_nohash_1.wav
# ./on/9a7c1f83_nohash_2.wav
# ./on/28ce0c58_nohash_1.wav
# ./on/15c563d7_nohash_2.wav
# ./on/8a5acefd_nohash_0.wav
# ./on/b5552931_nohash_3.wav
# ./on/0e5193e6_nohash_0.wav
# ./on/7318280c_nohash_1.wav
# ./on/c634a189_nohash_2.wav
# ./on/747e69fd_nohash_1.wav
# ./on/72aa7259_nohash_0.wav
# ./on/742d6431_nohash_0.wav
# ./on/590750e8_nohash_1.wav
# ./on/951cac20_nohash_0.wav
# ./on/130d9a87_nohash_0.wav
# ./on/439c84f4_nohash_1.wav
# ./on/924c1a04_nohash_0.wav
# ./on/f15a354c_nohash_0.wav
# ./on/70a00e98_nohash_4.wav
# ./on/da15e796_nohash_0.wav
# ./on/8d8d9855_nohash_0.wav
# ./on/ed3c2d05_nohash_1.wav
# ./on/d9ae8983_nohash_0.wav
# ./on/c518d1b1_nohash_0.wav
# ./on/d0faf7e4_nohash_3.wav
# ./on/3c257192_nohash_4.wav
# ./on/a74f3917_nohash_0.wav
# ./on/1a9afd33_nohash_0.wav
# ./on/eb3f7d82_nohash_0.wav
# ./on/18a8f03f_nohash_0.wav
# ./on/7f74626f_nohash_0.wav
# ./on/7329545b_nohash_0.wav
# ./on/d7467392_nohash_2.wav
# ./on/2197f41c_nohash_0.wav
# ./on/d430b3cc_nohash_0.wav
# ./on/24c9f572_nohash_1.wav
# ./on/b544d4fd_nohash_0.wav
# ./on/840c366d_nohash_1.wav
# ./on/d94eb94f_nohash_0.wav
# ./on/f5733968_nohash_1.wav
# ./on/c948d727_nohash_2.wav
# ./on/876c84d6_nohash_0.wav
# ./on/7f74626f_nohash_3.wav
# ./on/e1469561_nohash_4.wav
# ./on/6301e683_nohash_0.wav
# ./on/d197e3ae_nohash_1.wav
# ./on/1a073312_nohash_0.wav
# ./on/ecbd8d66_nohash_0.wav
# ./on/44f68a83_nohash_0.wav
# ./on/ccea893d_nohash_0.wav
# ./on/d926bb17_nohash_0.wav
# ./on/5be23def_nohash_0.wav
# ./on/e96a5020_nohash_2.wav
# ./on/1b755c65_nohash_3.wav
# ./on/e63b69c5_nohash_1.wav
# ./on/4a1e736b_nohash_1.wav
# ./on/8fe52b97_nohash_1.wav
# ./on/3e31dffe_nohash_0.wav
# ./on/28ed6bc9_nohash_2.wav
# ./on/e0315cf6_nohash_2.wav
# ./on/67961766_nohash_0.wav
# ./on/88a487ce_nohash_0.wav
# ./on/27c30960_nohash_0.wav
# ./on/b9f46737_nohash_3.wav
# ./on/ec74a8a5_nohash_1.wav
# ./on/41777abb_nohash_0.wav
# ./on/8134f43f_nohash_3.wav
# ./on/6a497f80_nohash_0.wav
# ./on/93f30cc4_nohash_0.wav
# ./on/5b09db89_nohash_2.wav
# ./on/25132942_nohash_4.wav
# ./on/3bc21161_nohash_2.wav
# ./on/763188c4_nohash_1.wav
# ./on/ab353673_nohash_0.wav
# ./on/099d52ad_nohash_2.wav
# ./on/e7ea8b76_nohash_3.wav
# ./on/b665723d_nohash_1.wav
# ./on/e855b8f1_nohash_0.wav
# ./on/b8897f1c_nohash_0.wav
# ./on/333784b7_nohash_1.wav
# ./on/5e3dde6b_nohash_4.wav
# ./on/a1cff772_nohash_2.wav
# ./on/0c2ca723_nohash_0.wav
# ./on/d0faf7e4_nohash_0.wav
# ./on/8eb4a1bf_nohash_3.wav
# ./on/7846fd85_nohash_4.wav
# ./on/5aac2efa_nohash_2.wav
# ./on/0447d7c1_nohash_0.wav
# ./on/51055bda_nohash_2.wav
# ./on/6166ae21_nohash_0.wav
# ./on/d9e9f554_nohash_2.wav
# ./on/fb7c9b3b_nohash_1.wav
# ./on/d1214f15_nohash_0.wav
# ./on/59fe87e6_nohash_0.wav
# ./on/8f4c551f_nohash_0.wav
# ./on/b9cccd01_nohash_0.wav
# ./on/ced835d3_nohash_2.wav
# ./on/ac7840d8_nohash_1.wav
# ./on/dc269564_nohash_0.wav
# ./on/9aa21fa9_nohash_4.wav
# ./on/437455be_nohash_0.wav
# ./on/b46e8153_nohash_0.wav
# ./on/fd395b74_nohash_0.wav
# ./on/863880b7_nohash_0.wav
# ./on/b9db6e42_nohash_1.wav
# ./on/bab36420_nohash_0.wav
# ./on/92a9c5e6_nohash_1.wav
# ./on/6e41a77e_nohash_0.wav
# ./on/61d3e51e_nohash_0.wav
# ./on/789e4ee7_nohash_0.wav
# ./on/4c77947d_nohash_0.wav
# ./on/418e7158_nohash_0.wav
# ./on/e1469561_nohash_1.wav
# ./on/5de3f6cc_nohash_2.wav
# ./on/09ddc105_nohash_0.wav
# ./on/38d78313_nohash_1.wav
# ./on/ccf418a5_nohash_0.wav
# ./on/da584bc0_nohash_4.wav
# ./on/953fe1ad_nohash_3.wav
# ./on/ec201020_nohash_3.wav
# ./on/da584bc0_nohash_0.wav
# ./on/8e05039f_nohash_0.wav
# ./on/c256377f_nohash_0.wav
# ./on/cc6ee39b_nohash_0.wav
# ./on/c1b7c224_nohash_1.wav
# ./on/a8f45bdc_nohash_1.wav
# ./on/6c429c7b_nohash_2.wav
# ./on/37b03ab1_nohash_0.wav
# ./on/7eee5973_nohash_2.wav
# ./on/87eff300_nohash_0.wav
# ./on/408de0a4_nohash_0.wav
# ./on/bbd0bbd0_nohash_1.wav
# ./on/716757ce_nohash_1.wav
# ./on/7ea032f3_nohash_3.wav
# ./on/d3badc9a_nohash_0.wav
# ./on/c24d96eb_nohash_1.wav
# ./on/d0faf7e4_nohash_5.wav
# ./on/49f30eed_nohash_0.wav
# ./on/023a61ad_nohash_0.wav
# ./on/8012c69d_nohash_1.wav
# ./on/d7467392_nohash_0.wav
# ./on/122c5aa7_nohash_1.wav
# ./on/88e90bc1_nohash_1.wav
# ./on/e7334395_nohash_0.wav
# ./on/96cd0255_nohash_0.wav
# ./on/627c0bec_nohash_0.wav
# ./on/b843de62_nohash_0.wav
# ./on/6af4aa07_nohash_0.wav
# ./on/b843de62_nohash_1.wav
# ./on/d9e9f554_nohash_1.wav
# ./on/325a0c39_nohash_1.wav
# ./on/2151b09a_nohash_0.wav
# ./on/6a014b29_nohash_2.wav
# ./on/c1d39ce8_nohash_7.wav
# ./on/b43de700_nohash_2.wav
# ./on/db43cd03_nohash_0.wav
# ./on/21832144_nohash_2.wav
# ./on/1b755c65_nohash_1.wav
# ./on/8f4c551f_nohash_1.wav
# ./on/1b459024_nohash_1.wav
# ./on/919d3c0e_nohash_0.wav
# ./on/7dc50b88_nohash_0.wav
# ./on/0f3f64d5_nohash_1.wav
# ./on/07ad9b59_nohash_0.wav
# ./on/f632210f_nohash_0.wav
# ./on/f5733968_nohash_3.wav
# ./on/1b4c9b89_nohash_3.wav
# ./on/6c2dd2d5_nohash_0.wav
# ./on/7ea032f3_nohash_1.wav
# ./on/7e783e3f_nohash_3.wav
# ./on/2a0b413e_nohash_0.wav
# ./on/cae62f38_nohash_0.wav
# ./on/e54a0f16_nohash_1.wav
# ./on/6c429c7b_nohash_1.wav
# ./on/1657c9fa_nohash_1.wav
# ./on/e57abea3_nohash_0.wav
# ./on/65d14087_nohash_0.wav
# ./on/2f813234_nohash_0.wav
# ./on/3aa6f4e2_nohash_0.wav
# ./on/789e4ee7_nohash_1.wav
# ./on/3bfd30e6_nohash_1.wav
# ./on/bb31b82b_nohash_0.wav
# ./on/ffd2ba2f_nohash_3.wav
# ./on/8910e5ef_nohash_1.wav
# ./on/9b027ecf_nohash_0.wav
# ./on/c1b7c224_nohash_0.wav
# ./on/e1469561_nohash_2.wav
# ./on/6727b579_nohash_1.wav
# ./on/ffd2ba2f_nohash_2.wav
# ./on/f5733968_nohash_4.wav
# ./on/aef8dcf5_nohash_0.wav
# ./on/c79159aa_nohash_1.wav
# ./on/5b1db3ee_nohash_0.wav
# ./on/df1d5024_nohash_2.wav
# ./on/8281a2a8_nohash_1.wav
# ./on/a6d586b7_nohash_4.wav
# ./on/d197e3ae_nohash_2.wav
# ./on/093f65a1_nohash_1.wav
# ./on/c1d39ce8_nohash_0.wav
# ./on/89d6d11e_nohash_0.wav
# ./on/f5e44d34_nohash_1.wav
# ./on/988e2f9a_nohash_0.wav
# ./on/229978fd_nohash_2.wav
# ./on/7117fb6d_nohash_0.wav
# ./on/ec545975_nohash_0.wav
# ./on/85834399_nohash_0.wav
# ./on/e5c48e53_nohash_1.wav
# ./on/6c968bd9_nohash_0.wav
# ./on/a8f45bdc_nohash_0.wav
# ./on/59c3a7f2_nohash_0.wav
# ./on/bfa63751_nohash_0.wav
# ./on/229978fd_nohash_4.wav
# ./on/61e50f62_nohash_1.wav
# ./on/9ff2d2f4_nohash_3.wav
# ./on/fac7deca_nohash_0.wav
# ./on/9a8d8d34_nohash_0.wav
# ./on/6c2dd2d5_nohash_1.wav
# ./on/2313e093_nohash_0.wav
# ./on/118261a9_nohash_1.wav
# ./on/da584bc0_nohash_1.wav
# ./on/eb3f7d82_nohash_4.wav
# ./on/52bfbce8_nohash_1.wav
# ./on/e0611c84_nohash_1.wav
# ./on/ceaadb24_nohash_0.wav
# ./on/c9b653a0_nohash_0.wav
# ./on/837f7378_nohash_0.wav
# ./on/6a700f9d_nohash_1.wav
# ./on/a60a09cf_nohash_0.wav
# ./on/6c9223bd_nohash_1.wav
# ./on/9a7c1f83_nohash_0.wav
# ./on/c9b653a0_nohash_4.wav
# ./on/2f666bb2_nohash_0.wav
# ./on/fb9d6d23_nohash_0.wav
# ./on/99b05bcf_nohash_0.wav
# ./on/d1a17cbe_nohash_2.wav
# ./on/964e8cfd_nohash_0.wav
# ./on/0b09edd3_nohash_1.wav
# ./on/4c841771_nohash_1.wav
# ./on/d90b4138_nohash_1.wav
# ./on/c1d39ce8_nohash_6.wav
# ./on/70a00e98_nohash_2.wav
# ./on/29fb33da_nohash_0.wav
# ./on/3bfd30e6_nohash_3.wav
# ./on/b8c48ffb_nohash_0.wav
# ./on/5e3dde6b_nohash_0.wav
# ./on/df1d5024_nohash_0.wav
# ./on/e20be42a_nohash_0.wav
# ./on/fb7c9b3b_nohash_0.wav
# ./on/54d9ccb5_nohash_0.wav
# ./on/50ed8a7b_nohash_1.wav
# ./on/888a0c49_nohash_4.wav
# ./on/88f8a99c_nohash_0.wav
# ./on/c22d3f18_nohash_0.wav
# ./on/2fa39636_nohash_0.wav
# ./on/2bdbe5f7_nohash_3.wav
# ./on/c692524d_nohash_0.wav
# ./on/f8ad3941_nohash_1.wav
# ./on/264f471d_nohash_3.wav
# ./on/9a356ab9_nohash_0.wav
# ./on/8c7f81df_nohash_1.wav
# ./on/5c39594f_nohash_0.wav
# ./on/651d108f_nohash_0.wav
# ./on/ced835d3_nohash_3.wav
# ./on/1a4259c3_nohash_0.wav
# ./on/264f471d_nohash_4.wav
# ./on/fac74f6a_nohash_0.wav
# ./on/651d108f_nohash_1.wav
# ./on/a8ee11c7_nohash_0.wav
# ./on/89d6d11e_nohash_2.wav
# ./on/afe0b87d_nohash_0.wav
# ./on/c0e0f834_nohash_0.wav
# ./on/c50225fa_nohash_0.wav
# ./on/bbbf4fbd_nohash_0.wav
# ./on/49af4432_nohash_0.wav
# ./on/86fa2dcd_nohash_0.wav
# ./on/dbb40d24_nohash_2.wav
# ./on/918a2473_nohash_1.wav
# ./on/43f57297_nohash_0.wav
# ./on/333784b7_nohash_4.wav
# ./on/86402da1_nohash_0.wav
# ./on/cd8b1781_nohash_1.wav
# ./on/21832144_nohash_3.wav
# ./on/c120e80e_nohash_3.wav
# ./on/16db1582_nohash_0.wav
# ./on/73cccfaf_nohash_2.wav
# ./on/1aeef15e_nohash_1.wav
# ./on/0ff728b5_nohash_2.wav
# ./on/3c257192_nohash_1.wav
# ./on/4407ba92_nohash_0.wav
# ./on/5b09db89_nohash_3.wav
# ./on/bab36420_nohash_2.wav
# ./on/f3957e23_nohash_0.wav
# ./on/65d844fc_nohash_0.wav
# ./on/1851e33b_nohash_0.wav
# ./on/bbaa7946_nohash_0.wav
# ./on/1fe4c891_nohash_0.wav
# ./on/1df99a8a_nohash_0.wav
# ./on/38d78313_nohash_3.wav
# ./on/78884794_nohash_0.wav
# ./on/1b835b87_nohash_0.wav
# ./on/096456f9_nohash_0.wav
# ./on/9a43b64b_nohash_0.wav
# ./on/dca2797e_nohash_0.wav
# ./on/87014d40_nohash_0.wav
# ./on/d1214f15_nohash_1.wav
# ./on/cb8f8307_nohash_4.wav
# ./on/964e8cfd_nohash_4.wav
# ./on/837f7378_nohash_2.wav
# ./on/3bdf05d3_nohash_0.wav
# ./on/3b852f6f_nohash_0.wav
# ./on/5a0bc987_nohash_0.wav
# ./on/4a1e736b_nohash_2.wav
# ./on/340c8b10_nohash_2.wav
# ./on/e9a76b2f_nohash_1.wav
# ./on/b31ad508_nohash_0.wav
# ./on/b3bdded5_nohash_0.wav
# ./on/2335770e_nohash_3.wav
# ./on/f953e1af_nohash_1.wav
# ./on/7e843da8_nohash_0.wav
# ./on/d1d3e64d_nohash_1.wav
# ./on/6078eb0d_nohash_0.wav
# ./on/1a5b9ca4_nohash_0.wav
# ./on/b959cd0c_nohash_3.wav
# ./on/a4c938ce_nohash_1.wav
# ./on/97addd88_nohash_0.wav
# ./on/15c563d7_nohash_0.wav
# ./on/e57abea3_nohash_2.wav
# ./on/8012c69d_nohash_0.wav
# ./on/518588b6_nohash_0.wav
# ./on/f8f60f59_nohash_4.wav
# ./on/004ae714_nohash_1.wav
# ./on/97addd88_nohash_1.wav
# ./on/b3849d6e_nohash_0.wav
# ./on/370844f7_nohash_1.wav
# ./on/439c84f4_nohash_0.wav
# ./on/fc94edb0_nohash_0.wav
# ./on/2ad772d6_nohash_0.wav
# ./on/b7a0754f_nohash_2.wav
# ./on/2da58b32_nohash_3.wav
# ./on/3e31dffe_nohash_4.wav
# ./on/aa753bb9_nohash_1.wav
# ./on/a1cff772_nohash_3.wav
# ./on/6b889021_nohash_0.wav
# ./on/063d48cf_nohash_0.wav
# ./on/9f869f70_nohash_0.wav
# ./on/533c6564_nohash_0.wav
# ./on/cb8f8307_nohash_5.wav
# ./on/3fb8c268_nohash_0.wav
# ./on/51055bda_nohash_0.wav
# ./on/fcb25a78_nohash_0.wav
# ./on/f17be97f_nohash_0.wav
# ./on/9a69672b_nohash_3.wav
# ./on/1df99a8a_nohash_1.wav
# ./on/3e2ba5f7_nohash_1.wav
# ./on/1bc45db9_nohash_1.wav
# ./on/6c0f6493_nohash_4.wav
# ./on/cb802c63_nohash_0.wav
# ./on/e41a903b_nohash_1.wav
# ./on/9ff2d2f4_nohash_1.wav
# ./on/f7879738_nohash_0.wav
# ./on/283d7a53_nohash_1.wav
# ./on/15c563d7_nohash_3.wav
# ./on/1cc80e39_nohash_0.wav
# ./on/00b01445_nohash_0.wav
# ./on/408de0a4_nohash_1.wav
# ./on/b19f7f5f_nohash_0.wav
# ./on/01648c51_nohash_1.wav
# ./on/96ab6565_nohash_1.wav
# ./on/6301e683_nohash_1.wav
# ./on/857366dd_nohash_0.wav
# ./on/1b4c9b89_nohash_2.wav
# ./on/2335770e_nohash_0.wav
# ./on/25c14394_nohash_0.wav
# ./on/fbf3dd31_nohash_1.wav
# ./on/8134f43f_nohash_1.wav
# ./on/e53139ad_nohash_0.wav
# ./on/49af4432_nohash_3.wav
# ./on/f1d36c53_nohash_0.wav
# ./on/5f8e50a0_nohash_0.wav
# ./on/bbaa7946_nohash_1.wav
# ./on/6982fc2a_nohash_0.wav
# ./on/96105282_nohash_0.wav
# ./on/dc2222d7_nohash_0.wav
# ./on/8911b8d2_nohash_0.wav
# ./on/adec6a94_nohash_0.wav
# ./on/b83c1acf_nohash_0.wav
# ./on/a9f38bae_nohash_0.wav
# ./on/97f4c236_nohash_0.wav
# ./on/d90b4138_nohash_4.wav
# ./on/d33df435_nohash_1.wav
# ./on/df1d5024_nohash_3.wav
# ./on/5de8f2f0_nohash_3.wav
# ./on/94de6a6a_nohash_4.wav
# ./on/25132942_nohash_1.wav
# ./on/97ae8b25_nohash_0.wav
# ./on/a16b3102_nohash_0.wav
# ./on/bd11c654_nohash_1.wav
# ./on/324210dd_nohash_4.wav
# ./on/258f4559_nohash_0.wav
# ./on/b26343e9_nohash_0.wav
# ./on/e0322f2c_nohash_0.wav
# ./on/cc6ee39b_nohash_4.wav
# ./on/7cbf645a_nohash_1.wav
# ./on/afabfa0e_nohash_0.wav
# ./on/39dce8cc_nohash_1.wav
# ./on/d37e4bf1_nohash_0.wav
# ./on/1e9b215e_nohash_0.wav
# ./on/95218ce8_nohash_1.wav
# ./on/c11c1587_nohash_0.wav
# ./on/86b89661_nohash_1.wav
# ./on/b4bef564_nohash_0.wav
# ./on/377e916b_nohash_0.wav
# ./on/96c66ab7_nohash_0.wav
# ./on/e9a76b2f_nohash_0.wav
# ./on/eb0676ec_nohash_3.wav
# ./on/6ceeb9aa_nohash_0.wav
# ./on/8f4c551f_nohash_2.wav
# ./on/c7b4049e_nohash_0.wav
# ./on/6794a793_nohash_0.wav
# ./on/563aa4e6_nohash_3.wav
# ./on/93ec8b84_nohash_0.wav
# ./on/80c45ed6_nohash_0.wav
# ./on/3d53244b_nohash_3.wav
# ./on/5f1b1051_nohash_0.wav
# ./on/dca6b373_nohash_0.wav
# ./on/9a7c1f83_nohash_6.wav
# ./on/8eb4a1bf_nohash_0.wav
# ./on/6d2d3b0d_nohash_1.wav
# ./on/94de6a6a_nohash_1.wav
# ./on/173ce2be_nohash_0.wav
# ./on/2e30f9a5_nohash_0.wav
# ./on/f57469fb_nohash_0.wav
# ./on/07363607_nohash_1.wav
# ./on/fce65496_nohash_0.wav
# ./on/facd97c0_nohash_1.wav
# ./on/ed3c2d05_nohash_0.wav
# ./on/7c1d8533_nohash_3.wav
# ./on/2e0d80f7_nohash_1.wav
# ./on/022cd682_nohash_0.wav
# ./on/ad63d93c_nohash_3.wav
# ./on/da5dadb9_nohash_0.wav
# ./on/7c1d8533_nohash_2.wav
# ./on/b5552931_nohash_2.wav
# ./on/f0ae7203_nohash_1.wav
# ./on/5de3f6cc_nohash_0.wav
# ./on/e8d562ca_nohash_0.wav
# ./on/5c39594f_nohash_3.wav
# ./on/977a3be4_nohash_1.wav
# ./on/28ce0c58_nohash_0.wav
# ./on/f19d1738_nohash_1.wav
# ./on/9a7c1f83_nohash_1.wav
# ./on/7ea032f3_nohash_4.wav
# ./on/9a8d8d34_nohash_1.wav
# ./on/f19c1390_nohash_1.wav
# ./on/8c888bbb_nohash_1.wav
# ./on/be7a5b2d_nohash_0.wav
# ./on/b43c8f2f_nohash_0.wav
# ./on/300384f0_nohash_0.wav
# ./on/b9db6e42_nohash_0.wav
# ./on/bb31b82b_nohash_1.wav
# ./on/2bdbe5f7_nohash_2.wav
# ./on/772db621_nohash_0.wav
# ./on/b5552931_nohash_4.wav
# ./on/dd6c6806_nohash_1.wav
# ./on/fac74f6a_nohash_1.wav
# ./on/bc196f81_nohash_0.wav
# ./on/97e0c576_nohash_0.wav
# ./on/0132a06d_nohash_2.wav
# ./on/1bc45db9_nohash_0.wav
# ./on/bf5d409d_nohash_0.wav
# ./on/4e8c5516_nohash_0.wav
# ./on/06076b6b_nohash_0.wav
# ./on/f5733968_nohash_2.wav
# ./on/5f1b1051_nohash_1.wav
# ./on/aba19127_nohash_0.wav
# ./on/888a0c49_nohash_3.wav
# ./on/a1dd919f_nohash_0.wav
# ./on/cd7f8c1b_nohash_1.wav
# ./on/96a48d28_nohash_4.wav
# ./on/21e8c417_nohash_0.wav
# ./on/1b835b87_nohash_2.wav
# ./on/dbb40d24_nohash_3.wav
# ./on/b49caed3_nohash_1.wav
# ./on/c1d39ce8_nohash_9.wav
# ./on/f5496439_nohash_2.wav
# ./on/ad63d93c_nohash_2.wav
# ./on/3402e488_nohash_0.wav
# ./on/571c044e_nohash_2.wav
# ./on/0132a06d_nohash_0.wav
# ./on/5a3712c9_nohash_1.wav
# ./on/d7467392_nohash_1.wav
# ./on/324210dd_nohash_3.wav
# ./on/784e281a_nohash_0.wav
# ./on/5236848b_nohash_0.wav
# ./on/e10e2cbb_nohash_0.wav
# ./on/637c702a_nohash_0.wav
# ./on/94de6a6a_nohash_0.wav
# ./on/591d32f3_nohash_1.wav
# ./on/ea9f8e11_nohash_0.wav
# ./on/d9b50b8b_nohash_2.wav
# ./on/66cff190_nohash_0.wav
# ./on/3ed3e49a_nohash_1.wav
# ./on/eb0676ec_nohash_1.wav
# ./on/b49caed3_nohash_3.wav
# ./on/3209ec42_nohash_0.wav
# ./on/3c257192_nohash_3.wav
# ./on/9d7036f9_nohash_0.wav
# ./on/a16b3102_nohash_1.wav
# ./on/f19c1390_nohash_3.wav
# ./on/0f7205ef_nohash_0.wav
# ./on/61a9f72a_nohash_3.wav
# ./on/f0ac2522_nohash_1.wav
# ./on/2a89ad5c_nohash_1.wav
# ./on/c120e80e_nohash_0.wav
# ./on/4f8ef132_nohash_0.wav
# ./on/7c1d8533_nohash_5.wav
# ./on/50928b05_nohash_0.wav
# ./on/4845bb10_nohash_0.wav
# ./on/413bcfe1_nohash_0.wav
# ./on/b4aa9fef_nohash_4.wav
# ./on/52bfbce8_nohash_0.wav
# ./on/95299b6c_nohash_1.wav
# ./on/8fe52b97_nohash_0.wav
# ./on/09ddc105_nohash_1.wav
# ./on/9aa21fa9_nohash_0.wav
# ./on/d90b4138_nohash_0.wav
# ./on/589bce2c_nohash_0.wav
# ./on/94de6a6a_nohash_3.wav
# ./on/c0445658_nohash_0.wav
# ./on/a8e25ebb_nohash_0.wav
# ./on/d9b8fab2_nohash_0.wav
# ./on/b8b8cb52_nohash_0.wav
# ./on/1dce06e8_nohash_0.wav
# ./on/9f4098cb_nohash_1.wav
# ./on/3d53244b_nohash_0.wav
# ./on/cb2929ce_nohash_5.wav
# ./on/9b6c08ba_nohash_0.wav
# ./on/f2dd248e_nohash_0.wav
# ./on/3ea77ede_nohash_0.wav
# ./on/0132a06d_nohash_1.wav
# ./on/c120e80e_nohash_4.wav
# ./on/0132a06d_nohash_3.wav
# ./on/a6d586b7_nohash_3.wav
# ./on/ad1429cf_nohash_1.wav
# ./on/b959cd0c_nohash_4.wav
# ./on/24b82192_nohash_0.wav
# ./on/712e4d58_nohash_1.wav
# ./on/686d030b_nohash_0.wav
# ./on/df1d5024_nohash_4.wav
# ./on/3903b558_nohash_0.wav
# ./on/dbaf8fc6_nohash_0.wav
# ./on/2bdbe5f7_nohash_4.wav
# ./on/28ce0c58_nohash_3.wav
# ./on/18a8f03f_nohash_1.wav
# ./on/25132942_nohash_2.wav
# ./on/2f813234_nohash_1.wav
# ./on/36050ef3_nohash_2.wav
# ./on/099d52ad_nohash_0.wav
# ./on/ced835d3_nohash_0.wav
# ./on/bd8412df_nohash_0.wav
# ./on/8bf6acb9_nohash_0.wav
# ./on/efbc3952_nohash_0.wav
# ./on/7fd25f7c_nohash_0.wav
# ./on/6727b579_nohash_0.wav
# ./on/de650823_nohash_1.wav
# ./on/15f04ff8_nohash_0.wav
# ./on/8281a2a8_nohash_2.wav
# ./on/5ff3f9a1_nohash_0.wav
# ./on/c7aaad67_nohash_0.wav
# ./on/6094340e_nohash_0.wav
# ./on/f292725f_nohash_0.wav
# ./on/e3b64217_nohash_0.wav
# ./on/782c1305_nohash_2.wav
# ./on/4f781a59_nohash_0.wav
# ./on/105a0eea_nohash_1.wav
# ./on/a4c938ce_nohash_0.wav
# ./on/01bcfc0c_nohash_1.wav
# ./on/15c563d7_nohash_4.wav
# ./on/e96a5020_nohash_0.wav
# ./on/de41f895_nohash_0.wav
# ./on/f953e1af_nohash_2.wav
# ./on/e07dd7d4_nohash_0.wav
# ./on/bab36420_nohash_1.wav
# ./on/3f2b358d_nohash_1.wav
# ./on/e7ebf59c_nohash_0.wav
# ./on/7c1d8533_nohash_0.wav
# ./on/d90b4138_nohash_2.wav
# ./on/520e8c0e_nohash_1.wav
# ./on/27b9a84f_nohash_1.wav
# ./on/439c84f4_nohash_2.wav
# ./on/15d83b54_nohash_0.wav
# ./on/efa16ffd_nohash_0.wav
# ./on/58df33b5_nohash_1.wav
# ./on/cd68e997_nohash_0.wav
# ./on/7fd25f7c_nohash_4.wav
# ./on/5b26c81b_nohash_0.wav
# ./on/2039b9c1_nohash_0.wav
# ./on/3e3fa7fd_nohash_0.wav
# ./on/44f68a83_nohash_1.wav
# ./on/305776dd_nohash_0.wav
# ./on/551e42e8_nohash_0.wav
# ./on/a1c63f25_nohash_0.wav
# ./on/5ab63b0a_nohash_0.wav
# ./on/e7ea8b76_nohash_0.wav
# ./on/eee5e541_nohash_0.wav
# ./on/c2aeb59d_nohash_0.wav
# ./on/471a0925_nohash_3.wav
# ./on/815f0f03_nohash_0.wav
# ./on/fbf3dd31_nohash_3.wav
# ./on/fd395b74_nohash_1.wav
# ./on/0e17f595_nohash_0.wav
# ./on/36050ef3_nohash_3.wav
# ./on/7be9f58a_nohash_0.wav
# ./on/df038de4_nohash_0.wav
# ./on/823353e5_nohash_0.wav
# ./on/f8f60f59_nohash_3.wav
# ./on/3565ca83_nohash_0.wav
# ./on/56f8a100_nohash_0.wav
# ./on/38d78313_nohash_4.wav
# ./on/ac899eb7_nohash_0.wav
# ./on/eb0676ec_nohash_4.wav
# ./on/af8b2f2c_nohash_0.wav
# ./on/48463cbc_nohash_0.wav
# ./on/214ccb20_nohash_0.wav
# ./on/840c366d_nohash_0.wav
# ./on/735845ab_nohash_1.wav
# ./on/099d52ad_nohash_3.wav
# ./on/0227998e_nohash_0.wav
# ./on/918a2473_nohash_0.wav
# ./on/b9515bf3_nohash_2.wav
# ./on/f9273a21_nohash_0.wav
# ./on/3ab9ba07_nohash_1.wav
# ./on/78102205_nohash_0.wav
# ./on/590750e8_nohash_0.wav
# ./on/d6360b32_nohash_0.wav
# ./on/765ffccb_nohash_0.wav
# ./on/9cde5de8_nohash_0.wav
# ./on/e4b02540_nohash_0.wav
# ./on/6d818f6c_nohash_0.wav
# ./on/73cccfaf_nohash_0.wav
# ./on/1d1fe0a0_nohash_1.wav
# ./on/0819edb0_nohash_0.wav
# ./on/3da7f617_nohash_1.wav
# ./on/c0e8f5a1_nohash_0.wav
# ./on/c93d5e22_nohash_4.wav
# ./on/35d1b6ee_nohash_4.wav
# ./on/264f471d_nohash_1.wav
# ./on/cb2929ce_nohash_1.wav
# ./on/d0858dce_nohash_0.wav
# ./on/5d0ab165_nohash_0.wav
# ./on/36050ef3_nohash_4.wav
# ./on/47d01978_nohash_0.wav
# ./on/a243fcc2_nohash_0.wav
# ./on/23abe1c9_nohash_0.wav
# ./on/b80d6c5e_nohash_1.wav
# ./on/8e05039f_nohash_4.wav
# ./on/364c0853_nohash_1.wav
# ./on/3209ec42_nohash_1.wav
# ./on/d069e6ff_nohash_1.wav
# ./on/74b73f88_nohash_1.wav
# ./on/2b42e7a2_nohash_0.wav
# ./on/8dc26a15_nohash_0.wav
# ./on/d9b50b8b_nohash_1.wav
# ./on/c4f875a9_nohash_0.wav
# ./on/97f4c236_nohash_4.wav
# ./on/46a153d8_nohash_3.wav
# ./on/d6b155a5_nohash_0.wav
# ./on/a2fefcb4_nohash_1.wav
# ./on/64f83f0e_nohash_1.wav
# ./on/7cfb1618_nohash_0.wav
# ./on/f3d06008_nohash_1.wav
# ./on/6c0f6493_nohash_1.wav
# ./on/dc7ec25b_nohash_1.wav
# ./on/0ac15fe9_nohash_1.wav
# ./on/c5e3817f_nohash_1.wav
# ./on/44260689_nohash_0.wav
# ./on/41474817_nohash_0.wav
# ./on/6a861f21_nohash_1.wav
# ./on/cb2929ce_nohash_2.wav
# ./on/fbf3dd31_nohash_2.wav
# ./on/ab7b5acd_nohash_0.wav
# ./on/b16f2d0d_nohash_0.wav
# ./on/9886d8bf_nohash_3.wav
# ./on/7211390b_nohash_4.wav
# ./on/05b2db80_nohash_0.wav
# ./on/40115b19_nohash_0.wav
# ./on/0cd323ec_nohash_0.wav
# ./on/51995cea_nohash_0.wav
# ./on/39543cfd_nohash_1.wav
# ./on/338dacf5_nohash_0.wav
# ./on/e6db3894_nohash_1.wav
# ./on/0137b3f4_nohash_1.wav
# ./on/33903159_nohash_2.wav
# ./on/42c6fff1_nohash_0.wav
# ./on/57b38f48_nohash_0.wav
# ./on/c6ee87a7_nohash_1.wav
# ./on/db79a764_nohash_0.wav
# ./on/d9b50b8b_nohash_0.wav
# ./on/66276b0e_nohash_0.wav
# ./on/e55a2b20_nohash_2.wav
# ./on/283d7a53_nohash_0.wav
# ./on/b43de700_nohash_1.wav
# ./on/f44f440f_nohash_1.wav
# ./on/c0f8f4df_nohash_0.wav
# ./on/c0e8f5a1_nohash_1.wav
# ./on/d874a786_nohash_0.wav
# ./on/53fd1780_nohash_0.wav
# ./on/b9f46737_nohash_1.wav
# ./on/5c39594f_nohash_2.wav
# ./on/06076b6b_nohash_2.wav
# ./on/412c675c_nohash_0.wav
# ./on/563aa4e6_nohash_2.wav
# ./on/c1d39ce8_nohash_8.wav
# ./on/611d2b50_nohash_1.wav
# ./on/3ffa3457_nohash_0.wav
# ./on/07363607_nohash_0.wav
# ./on/a4e8a997_nohash_0.wav
# ./on/037c445a_nohash_0.wav
# ./on/e71b4ce6_nohash_0.wav
# ./on/5fe4a278_nohash_1.wav
# ./on/82e7204d_nohash_1.wav
# ./on/471a0925_nohash_0.wav
# ./on/92037d73_nohash_1.wav
# ./on/6d2d3b0d_nohash_0.wav
# ./on/6d0ad764_nohash_1.wav
# ./on/13199b79_nohash_2.wav
# ./on/5fadb538_nohash_1.wav
# ./on/cf68fad2_nohash_1.wav
# ./on/f9273a21_nohash_1.wav
# ./on/62641b88_nohash_0.wav
# ./on/460f2bad_nohash_1.wav
# ./on/826268f8_nohash_0.wav
# ./on/b7a0754f_nohash_4.wav
# ./on/9ff2d2f4_nohash_4.wav
# ./on/0f3f64d5_nohash_0.wav
# ./on/e0611c84_nohash_0.wav
# ./on/b2fbe484_nohash_0.wav
# ./on/b575b5fb_nohash_0.wav
# ./on/86f12ac0_nohash_0.wav
# ./on/07c5129e_nohash_0.wav
# ./on/de6eb27c_nohash_0.wav
# ./on/b9f46737_nohash_0.wav
# ./on/c885a039_nohash_0.wav
# ./on/5eb5fc74_nohash_1.wav
# ./on/f9bdf10e_nohash_0.wav
# ./on/692a88e6_nohash_2.wav
# ./on/51055bda_nohash_1.wav
# ./on/605ed0ff_nohash_0.wav
# ./on/39a12648_nohash_3.wav
# ./on/7fc74fbe_nohash_0.wav
# ./on/6f2f57c1_nohash_0.wav
# ./on/d9e9f554_nohash_0.wav
# ./on/45864319_nohash_0.wav
# ./on/fa44fcf5_nohash_0.wav
# ./on/75915c90_nohash_0.wav
# ./on/0b56bcfe_nohash_0.wav
# ./on/0ff728b5_nohash_3.wav
# ./on/5184ed3e_nohash_1.wav
# ./on/2f0a410b_nohash_0.wav
# ./on/35c8fa78_nohash_1.wav
# ./on/5db0e146_nohash_1.wav
# ./on/5fb88f4c_nohash_1.wav
# ./on/2b1dffa7_nohash_0.wav
# ./on/5c39594f_nohash_1.wav
# ./on/3a33d3a4_nohash_0.wav
# ./on/270bfa52_nohash_0.wav
# ./on/aff582a1_nohash_2.wav
# ./on/5be23def_nohash_1.wav
# ./on/59b98a22_nohash_0.wav
# ./on/190821dc_nohash_1.wav
# ./on/21832144_nohash_0.wav
# ./on/be7a5b2d_nohash_2.wav
# ./on/65ec06e5_nohash_0.wav
# ./on/5f1b1051_nohash_2.wav
# ./on/7846fd85_nohash_3.wav
# ./on/2bdbe5f7_nohash_1.wav
# ./on/d926bb17_nohash_1.wav
# ./on/964e8cfd_nohash_1.wav
# ./on/ae04cdbe_nohash_0.wav
# ./on/01bb6a2a_nohash_0.wav
# ./on/888a0c49_nohash_2.wav
# ./on/0c5027de_nohash_0.wav
# ./on/324210dd_nohash_1.wav
# ./on/35d1b6ee_nohash_0.wav
# ./on/743edf9d_nohash_0.wav
# ./on/dc7ec25b_nohash_0.wav
# ./on/ec201020_nohash_1.wav
# ./on/92a9c5e6_nohash_2.wav
# ./on/f92e49f3_nohash_1.wav
# ./on/96d5276f_nohash_0.wav
# ./on/dce05676_nohash_0.wav
# ...
# ./happy/c4533c47_nohash_0.wav
# ./happy/6f3458b3_nohash_1.wav
# ./happy/77f185d3_nohash_1.wav
# ./happy/e5d2e09d_nohash_0.wav
# ./happy/afb9e62e_nohash_1.wav
# ./happy/bca56796_nohash_1.wav
# ./happy/c2e08f08_nohash_1.wav
# ./happy/611d2b50_nohash_0.wav
# ./happy/13d7b8c9_nohash_2.wav
# ./happy/6021f08b_nohash_0.wav
# ./happy/d8c52371_nohash_2.wav
# ./happy/de08912f_nohash_1.wav
# ./happy/573cdb8a_nohash_0.wav
# ./happy/692a88e6_nohash_0.wav
# ./happy/f19d1738_nohash_0.wav
# ./happy/264f471d_nohash_0.wav
# ./happy/26e573a9_nohash_1.wav
# ./happy/f06190c1_nohash_0.wav
# ./happy/409c962a_nohash_0.wav
# ./happy/2b3f509b_nohash_0.wav
# ./happy/f953e1af_nohash_0.wav
# ./happy/bd2db1a5_nohash_0.wav
# ./happy/af405b69_nohash_0.wav
# ./happy/1f3bece8_nohash_0.wav
# ./happy/89f680f3_nohash_0.wav
# ./happy/27c30960_nohash_1.wav
# ./happy/5fe4a278_nohash_0.wav
# ./happy/13d7b8c9_nohash_1.wav
# ./happy/e0344f60_nohash_1.wav
# ./happy/1746d7b6_nohash_1.wav
# ./happy/763188c4_nohash_0.wav
# ./happy/67c7fecb_nohash_0.wav
# ./happy/47565088_nohash_0.wav
# ./happy/bca56796_nohash_3.wav
# ./happy/dce5041a_nohash_0.wav
# ./happy/0f250098_nohash_0.wav
# ./happy/43691f67_nohash_1.wav
# ./happy/1ed557b9_nohash_0.wav
# ./happy/1626bc5a_nohash_0.wav
# ./happy/093f65a1_nohash_0.wav
# ./happy/587f3271_nohash_0.wav
# ./happy/257e17e0_nohash_0.wav
# ./happy/9f22307d_nohash_1.wav
# ./happy/9d050657_nohash_0.wav
# ./happy/3ae5c04f_nohash_2.wav
# ./happy/2bdbe5f7_nohash_0.wav
# ./happy/6940f7f3_nohash_0.wav
# ./happy/179a61b7_nohash_0.wav
# ./happy/6794a793_nohash_2.wav
# ./happy/cd7f8c1b_nohash_0.wav
# ./happy/fbf3dd31_nohash_0.wav
# ./happy/ec5ab5d5_nohash_0.wav
# ./happy/d7529c0c_nohash_1.wav
# ./happy/96c67073_nohash_0.wav
# ./happy/8c7b691a_nohash_0.wav
# ./happy/6846af18_nohash_0.wav
# ./happy/0bde966a_nohash_1.wav
# ./happy/c7b4049e_nohash_1.wav
# ./happy/76424fa5_nohash_1.wav
# ./happy/d069e6ff_nohash_0.wav
# ./happy/89e59d18_nohash_0.wav
# ./happy/5eb5fc74_nohash_0.wav
# ./happy/b5552931_nohash_0.wav
# ./happy/d750966e_nohash_1.wav
# ./happy/708b8d51_nohash_1.wav
# ./happy/6c0f6493_nohash_0.wav
# ./happy/50a8ef27_nohash_0.wav
# ./happy/92b0a735_nohash_0.wav
# ./happy/4f5c0b28_nohash_0.wav
# ./happy/77f185d3_nohash_0.wav
# ./happy/86cb59b2_nohash_0.wav
# ./happy/c50225fa_nohash_2.wav
# ./happy/a518d1cf_nohash_0.wav
# ./happy/402e2977_nohash_0.wav
# ./happy/d486fb84_nohash_1.wav
# ./happy/c38720cb_nohash_0.wav
# ./happy/b49caed3_nohash_0.wav
# ./happy/a40c62f1_nohash_0.wav
# ./happy/d312f481_nohash_4.wav
# ./happy/7b2e879e_nohash_0.wav
# ./happy/71aa5b54_nohash_0.wav
# ./happy/70a00e98_nohash_0.wav
# ./happy/71f9bba8_nohash_0.wav
# ./happy/05739450_nohash_0.wav
# ./happy/4bb1244f_nohash_1.wav
# ./happy/4249c833_nohash_0.wav
# ./happy/2d92f18b_nohash_0.wav
# ./happy/89ed36ab_nohash_1.wav
# ./happy/f297e878_nohash_0.wav
# ./happy/c0e0f834_nohash_1.wav
# ./happy/f875f965_nohash_0.wav
# ./happy/e72aa705_nohash_0.wav
# ./happy/0ac15fe9_nohash_0.wav
# ./happy/cab100c9_nohash_0.wav
# ./happy/4254621e_nohash_1.wav
# ./happy/fc28c8d8_nohash_0.wav
# ./happy/a108341b_nohash_0.wav
# ./happy/d750966e_nohash_0.wav
# ./happy/c2df23b2_nohash_0.wav
# ./happy/c6389ab0_nohash_0.wav
# ./happy/28e47b1a_nohash_0.wav
# ./happy/ea7ca285_nohash_0.wav
# ./happy/bd11a2e7_nohash_0.wav
# ./happy/6d0ad764_nohash_0.wav
# ./happy/50ed8a7b_nohash_2.wav
# ./happy/f8f60f59_nohash_0.wav
# ./happy/2a89ad5c_nohash_0.wav
# ./happy/1bb6ed89_nohash_0.wav
# ./happy/a4baac4e_nohash_0.wav
# ./happy/a50a98d2_nohash_0.wav
# ./happy/412c675c_nohash_1.wav
# ./happy/fce96bac_nohash_0.wav
# ./happy/66aa0f29_nohash_0.wav
# ./happy/981e2a16_nohash_1.wav
# ./happy/fc94edb0_nohash_1.wav
# ./happy/708b8d51_nohash_0.wav
# ./happy/c1e0e8e3_nohash_0.wav
# ./happy/fffcabd1_nohash_0.wav
# ./happy/060cd039_nohash_0.wav
# ./happy/823353e5_nohash_1.wav
# ./happy/460f2bad_nohash_0.wav
# ./happy/ef2a3cfb_nohash_0.wav
# ./happy/bfdb9801_nohash_0.wav
# ./happy/f6617a86_nohash_0.wav
# ./happy/9c59dd28_nohash_0.wav
# ./happy/377e916b_nohash_2.wav
# ./happy/e2008f39_nohash_0.wav
# ./happy/99b05bcf_nohash_1.wav
# ./happy/9080f6d3_nohash_0.wav
# ./happy/5fadb538_nohash_0.wav
# ./happy/e6db3894_nohash_0.wav
# ./happy/3b852f6f_nohash_1.wav
# ./happy/b21f0fa4_nohash_0.wav
# ./happy/126a31d2_nohash_2.wav
# ./happy/acde7e73_nohash_0.wav
# ./happy/459345ea_nohash_0.wav
# ./happy/88e90bc1_nohash_0.wav
# ./happy/b06c19b0_nohash_1.wav
# ./happy/d8c314c0_nohash_0.wav
# ./happy/4422e51d_nohash_2.wav
# ./happy/48a8a69d_nohash_0.wav
# ./happy/14872d06_nohash_0.wav
# ./happy/83f9c4ab_nohash_0.wav
# ./happy/a50a98d2_nohash_1.wav
# ./happy/8601f33b_nohash_0.wav
# ./happy/541e4079_nohash_1.wav
# ./happy/953fe1ad_nohash_0.wav
# ./happy/8a325749_nohash_0.wav
# ./happy/e9287461_nohash_0.wav
# ./happy/92037d73_nohash_0.wav
# ./happy/07c5129e_nohash_1.wav
# ./happy/8ed25ef8_nohash_1.wav
# ./happy/cfde27ba_nohash_1.wav
# ./happy/da1d320c_nohash_1.wav
# ./happy/13199b79_nohash_0.wav
# ./happy/27b03931_nohash_0.wav
# ./happy/e8e960fd_nohash_1.wav
# ./happy/c2e08f08_nohash_0.wav
# ./happy/50d1c8e3_nohash_1.wav
# ./happy/512dc91a_nohash_0.wav
# ./happy/76e53db9_nohash_1.wav
# ./happy/b93528e3_nohash_0.wav
# ./happy/6a014b29_nohash_0.wav
# ./happy/363c6bad_nohash_0.wav
# ./happy/6823565f_nohash_0.wav
# ./happy/3bfd30e6_nohash_0.wav
# ./happy/b087aa0e_nohash_0.wav
# ./happy/bd061bef_nohash_1.wav
# ./happy/becd5a53_nohash_1.wav
# ./happy/65c73b55_nohash_2.wav
# ./happy/39ec87ac_nohash_0.wav
# ./happy/060cd039_nohash_1.wav
# ./happy/650daf8e_nohash_0.wav
# ./happy/0ff728b5_nohash_0.wav
# ./happy/56f78b7e_nohash_0.wav
# ./happy/e04d7130_nohash_0.wav
# ./happy/ffbb695d_nohash_0.wav
# ./happy/d2eae23d_nohash_0.wav
# ./happy/151bfb79_nohash_0.wav
# ./happy/493392c6_nohash_0.wav
# ./happy/99a9b015_nohash_1.wav
# ./happy/11099149_nohash_0.wav
# ./happy/71aa5b54_nohash_1.wav
# ./happy/c842b5e4_nohash_0.wav
# ./happy/0362539c_nohash_1.wav
# ./happy/1c3f50ad_nohash_0.wav
# ./happy/39ec87ac_nohash_1.wav
# ./happy/76b58705_nohash_0.wav
# ./happy/36746d7f_nohash_0.wav
# ./happy/2d3c8dcb_nohash_0.wav
# ./happy/9637f43f_nohash_1.wav
# ./happy/7d8babdb_nohash_0.wav
# ./happy/54412eae_nohash_1.wav
# ./happy/3bdf05d3_nohash_1.wav
# ./happy/bfb10243_nohash_1.wav
# ./happy/b3327675_nohash_1.wav
# ./happy/67fcdb05_nohash_0.wav
# ./happy/5628d7b7_nohash_1.wav
# ./happy/83957201_nohash_1.wav
# ./happy/eb0676ec_nohash_0.wav
# ./happy/a84dee7b_nohash_0.wav
# ./happy/6c9223bd_nohash_0.wav
# ./happy/c392e01d_nohash_0.wav
# ./happy/8dd24423_nohash_0.wav
# ./happy/1995cf9e_nohash_0.wav
# ./happy/c5570933_nohash_0.wav
# ./happy/2bd2cad5_nohash_0.wav
# ./happy/7014b07e_nohash_0.wav
# ./happy/3e3b65eb_nohash_0.wav
# ./happy/340c8b10_nohash_0.wav
# ./happy/db43cd03_nohash_3.wav
# ./happy/5de8f2f0_nohash_0.wav
# ./happy/b9cccd01_nohash_1.wav
# ./happy/f92e49f3_nohash_0.wav
# ./happy/6094340e_nohash_1.wav
# ./happy/16d41d07_nohash_0.wav
# ./happy/6b81fead_nohash_0.wav
# ./happy/22aa3665_nohash_2.wav
# ./happy/b3327675_nohash_2.wav
# ./happy/c4500713_nohash_0.wav
# ./happy/3ff840aa_nohash_0.wav
# ./happy/ffd2ba2f_nohash_0.wav
# ./happy/ead2934a_nohash_0.wav
# ./happy/8f0d3c27_nohash_0.wav
# ./happy/cc2f1a85_nohash_0.wav
# ./happy/d3a18257_nohash_0.wav
# ./happy/370844f7_nohash_0.wav
# ./happy/c44d2a58_nohash_0.wav
# ./happy/8931f494_nohash_1.wav
# ./happy/bfbd0e6b_nohash_0.wav
# ./happy/d933bf5e_nohash_0.wav
# ./happy/d312f481_nohash_5.wav
# ./happy/3ff840aa_nohash_1.wav
# ./happy/ea356919_nohash_1.wav
# ./happy/b4aa9fef_nohash_0.wav
# ./happy/813b82a6_nohash_1.wav
# ./happy/042186b8_nohash_1.wav
# ./happy/e7117d00_nohash_0.wav
# ./happy/4290ca61_nohash_0.wav
# ./happy/833a0279_nohash_0.wav
# ./happy/435f9f9e_nohash_2.wav
# ./happy/e6e29c47_nohash_2.wav
# ./happy/d486fb84_nohash_0.wav
# ./happy/6d0ad764_nohash_2.wav
# ./happy/e8c3c5ca_nohash_0.wav
# ./happy/7d5f87c8_nohash_1.wav
# ./happy/f839238a_nohash_0.wav
# ./happy/6a2fb9a5_nohash_0.wav
# ./happy/1aed7c6d_nohash_0.wav
# ./happy/f59d0771_nohash_0.wav
# ./happy/e98cb283_nohash_0.wav
# ./happy/a3255f5c_nohash_0.wav
# ./happy/67c7fecb_nohash_1.wav
# ./happy/eee9b9e2_nohash_0.wav
# ./happy/ff21fb59_nohash_1.wav
# ./happy/1b459024_nohash_0.wav
# ./happy/9a69672b_nohash_0.wav
# ./happy/2d92f18b_nohash_1.wav
# ./happy/73dda36a_nohash_0.wav
# ./happy/c68cf200_nohash_1.wav
# ./happy/c948d727_nohash_0.wav
# ./happy/eb67fcbc_nohash_1.wav
# ./happy/e649aa92_nohash_0.wav
# ./happy/1dce06e8_nohash_1.wav
# ./happy/44bc77f7_nohash_0.wav
# ./happy/b01c8f61_nohash_0.wav
# ./happy/19f9c115_nohash_0.wav
# ./happy/86648261_nohash_0.wav
# ./happy/73f0c1f7_nohash_0.wav
# ./happy/a8cb6dda_nohash_0.wav
# ./happy/e6e29c47_nohash_3.wav
# ./happy/ccea893d_nohash_1.wav
# ./happy/4422e51d_nohash_1.wav
# ./happy/5588c7e6_nohash_1.wav
# ./happy/977a3be4_nohash_0.wav
# ./happy/f632210f_nohash_1.wav
# ./happy/44715c1c_nohash_1.wav
# ./happy/b487da60_nohash_2.wav
# ./happy/f5733968_nohash_0.wav
# ./happy/4fe01997_nohash_0.wav
# ./happy/dd086776_nohash_1.wav
# ./happy/4f086393_nohash_0.wav
# ./happy/ca4eeab0_nohash_0.wav
# ./happy/8442ea62_nohash_0.wav
# ./happy/b8c48ffb_nohash_1.wav
# ./happy/6f3458b3_nohash_0.wav
# ./happy/f4386675_nohash_0.wav
# ./happy/8549f25d_nohash_2.wav
# ./happy/0b09edd3_nohash_0.wav
# ./happy/b3bb4dd6_nohash_2.wav
# ./happy/a0a8d759_nohash_0.wav
# ./happy/bca56796_nohash_2.wav
# ./happy/d933bf5e_nohash_1.wav
# ./happy/b087aa0e_nohash_1.wav
# ./happy/bd061bef_nohash_2.wav
# ./happy/8a0457c9_nohash_0.wav
# ./happy/de040337_nohash_0.wav
# ./happy/50d1c8e3_nohash_0.wav
# ./happy/1e31353f_nohash_1.wav
# ./happy/bc196f81_nohash_1.wav
# ./happy/1995cf9e_nohash_1.wav
# ./happy/ad5aeec2_nohash_0.wav
# ./happy/f21893dc_nohash_0.wav
# ./happy/c71e3acc_nohash_0.wav
# ./happy/8549f25d_nohash_1.wav
# ./happy/b487da60_nohash_0.wav
# ./happy/1fd85ee4_nohash_3.wav
# ./happy/126a31d2_nohash_0.wav
# ./happy/61a9f72a_nohash_0.wav
# ./happy/d33df435_nohash_0.wav
# ./happy/f0ebef1b_nohash_0.wav
# ./happy/71f6fed7_nohash_0.wav
# ./happy/27b03931_nohash_1.wav
# ./happy/e91d173e_nohash_0.wav
# ./happy/65d81c54_nohash_0.wav
# ./happy/422f8cf1_nohash_0.wav
# ./happy/2aa787cf_nohash_0.wav
# ./happy/274c008f_nohash_1.wav
# ./happy/659b7fae_nohash_0.wav
# ./happy/a4b21cbc_nohash_1.wav
# ./happy/b72e58c9_nohash_0.wav
# ./happy/99081f4d_nohash_1.wav
# ./happy/079d1020_nohash_0.wav
# ./happy/7e1054e7_nohash_2.wav
# ./happy/9e075bf1_nohash_0.wav
# ./happy/48e8b82a_nohash_0.wav
# ./happy/a1533da4_nohash_1.wav
# ./happy/8a56f36e_nohash_0.wav
# ./happy/e6be0830_nohash_0.wav
# ./happy/50ed8a7b_nohash_0.wav
# ./happy/af30314d_nohash_1.wav
# ./happy/c68cf200_nohash_0.wav
# ./happy/5c8af87a_nohash_0.wav
# ./happy/b84f83d2_nohash_0.wav
# ./happy/8e884ec4_nohash_0.wav
# ./happy/7bae88ed_nohash_1.wav
# ./happy/7096522d_nohash_0.wav
# ./happy/59b98a22_nohash_1.wav
# ./happy/3006c271_nohash_0.wav
# ./happy/3df9a3d4_nohash_0.wav
# ./happy/21cbe292_nohash_0.wav
# ./happy/f5c3de1b_nohash_0.wav
# ./happy/518588b6_nohash_1.wav
# ./happy/079dfce3_nohash_0.wav
# ./happy/c4e1f6e0_nohash_0.wav
# ./happy/aff582a1_nohash_0.wav
# ./happy/fe5c4a7a_nohash_0.wav
# ./happy/126403d4_nohash_0.wav
# ./happy/c120e80e_nohash_1.wav
# ./happy/4d9e07cf_nohash_0.wav
# ./happy/f550b7dc_nohash_1.wav
# ./happy/29b81b73_nohash_0.wav
# ./happy/10c6d873_nohash_0.wav
# ./happy/6a861f21_nohash_0.wav
# ./happy/650daf8e_nohash_1.wav
# ./happy/c37a72d3_nohash_0.wav
# ./happy/38c388bc_nohash_0.wav
# ./happy/f42e234b_nohash_2.wav
# ./happy/8494fba8_nohash_1.wav
# ./happy/e4200516_nohash_0.wav
# ./happy/62581901_nohash_0.wav
# ./happy/eee9b9e2_nohash_1.wav
# ./happy/0b77ee66_nohash_1.wav
# ./happy/6c6aa323_nohash_0.wav
# ./happy/7e1054e7_nohash_1.wav
# ./happy/493392c6_nohash_1.wav
# ./happy/b665723d_nohash_0.wav
# ./happy/9785931e_nohash_1.wav
# ./happy/299c14b1_nohash_2.wav
# ./happy/30802c5d_nohash_0.wav
# ./happy/e2286c18_nohash_0.wav
# ./happy/8830e17f_nohash_0.wav
# ./happy/31270cb2_nohash_0.wav
# ./happy/e6e29c47_nohash_1.wav
# ./happy/87728a88_nohash_0.wav
# ./happy/6e74c582_nohash_0.wav
# ./happy/ac652c60_nohash_0.wav
# ./happy/079d1020_nohash_1.wav
# ./happy/3e2ba5f7_nohash_0.wav
# ./happy/7add4c5f_nohash_0.wav
# ./happy/6a203e0e_nohash_0.wav
# ./happy/3c8dc702_nohash_0.wav
# ./happy/2796ac50_nohash_0.wav
# ./happy/0c5027de_nohash_2.wav
# ./happy/435f9f9e_nohash_0.wav
# ./happy/6b889021_nohash_2.wav
# ./happy/aac5b7c1_nohash_0.wav
# ./happy/4a1e736b_nohash_0.wav
# ./happy/37e8db82_nohash_0.wav
# ./happy/070b49af_nohash_0.wav
# ./happy/5e033479_nohash_0.wav
# ./happy/079d1020_nohash_2.wav
# ./happy/840eab5a_nohash_0.wav
# ./happy/7c2a3fa4_nohash_0.wav
# ./happy/d312f481_nohash_3.wav
# ./happy/0616de09_nohash_0.wav
# ./happy/2cf28b70_nohash_0.wav
# ./happy/d197e3ae_nohash_0.wav
# ./happy/cdfbbe75_nohash_0.wav
# ./happy/531a5b8a_nohash_0.wav
# ./happy/71904de3_nohash_1.wav
# ./happy/fbdc07bb_nohash_0.wav
# ./happy/3ae5c04f_nohash_1.wav
# ./happy/553f1a79_nohash_1.wav
# ./happy/20d3f11f_nohash_0.wav
# ./happy/b36c27c2_nohash_3.wav
# ./happy/31583d30_nohash_0.wav
# ./happy/f192e6b4_nohash_0.wav
# ./happy/fb7cfe0e_nohash_0.wav
# ./happy/ba770f9b_nohash_0.wav
# ./happy/cc71bada_nohash_0.wav
# ./happy/5705a0f9_nohash_0.wav
# ./happy/5f814c23_nohash_0.wav
# ./happy/f216055e_nohash_2.wav
# ./happy/da15e796_nohash_1.wav
# ./happy/0c2d2ffa_nohash_0.wav
# ./happy/90804775_nohash_0.wav
# ./happy/1a892463_nohash_0.wav
# ./happy/2e73212b_nohash_0.wav
# ./happy/01648c51_nohash_0.wav
# ./happy/d31d8dd7_nohash_0.wav
# ./happy/53458368_nohash_0.wav
# ./happy/9bea2ac7_nohash_0.wav
# ./happy/b06c19b0_nohash_0.wav
# ./happy/1528225c_nohash_1.wav
# ./happy/e9b61425_nohash_0.wav
# ./happy/617de221_nohash_0.wav
# ./happy/4f2be90f_nohash_0.wav
# ./happy/53eb0a88_nohash_0.wav
# ./happy/199da2bf_nohash_0.wav
# ./happy/8781f4c1_nohash_0.wav
# ./happy/34881b10_nohash_0.wav
# ./happy/13d7b8c9_nohash_0.wav
# ./happy/eee5e541_nohash_1.wav
# ./happy/589bce2c_nohash_1.wav
# ./happy/52e228e9_nohash_0.wav
# ./happy/0362539c_nohash_0.wav
# ./happy/2c6446f7_nohash_1.wav
# ./happy/86cb59b2_nohash_1.wav
# ./happy/1c45ceb2_nohash_0.wav
# ./happy/126a31d2_nohash_1.wav
# ./happy/3d9200b9_nohash_0.wav
# ./happy/126403d4_nohash_2.wav
# ./happy/39a6b995_nohash_0.wav
# ./happy/988e2f9a_nohash_1.wav
# ./happy/fb01a182_nohash_0.wav
# ./happy/d6360b32_nohash_1.wav
# ./happy/6b889021_nohash_1.wav
# ./happy/653a48f5_nohash_0.wav
# ./happy/324210dd_nohash_0.wav
# ./happy/3ff840aa_nohash_2.wav
# ./happy/da4ef063_nohash_0.wav
# ./happy/329eab8a_nohash_0.wav
# ./happy/9d32f10a_nohash_3.wav
# ./happy/a42a88ff_nohash_1.wav
# ./happy/19e98e89_nohash_0.wav
# ./happy/97101ef3_nohash_0.wav
# ./happy/34263ab3_nohash_0.wav
# ./happy/0819edb0_nohash_1.wav
# ./happy/9e6bb505_nohash_0.wav
# ./happy/3b7f817e_nohash_0.wav
# ./happy/c205e625_nohash_1.wav
# ./happy/ea356919_nohash_2.wav
# ./happy/8a56f36e_nohash_1.wav
# ./happy/56eab10e_nohash_0.wav
# ./happy/8c7f81df_nohash_0.wav
# ./happy/bca56796_nohash_0.wav
# ./happy/d8ee4734_nohash_0.wav
# ./happy/7f17667c_nohash_0.wav
# ./happy/1ffd513b_nohash_0.wav
# ./happy/d0426d63_nohash_0.wav
# ./happy/86b89661_nohash_0.wav
# ./happy/a16b3102_nohash_2.wav
# ./happy/42beb5eb_nohash_0.wav
# ./happy/db43cd03_nohash_1.wav
# ./happy/d7ca14ef_nohash_0.wav
# ./happy/a583c5b0_nohash_1.wav
# ./happy/22aa3665_nohash_0.wav
# ./happy/6dfff95a_nohash_0.wav
# ./happy/e3411931_nohash_0.wav
# ./happy/dd086776_nohash_0.wav
# ./happy/f9f9751d_nohash_0.wav
# ./happy/c205e625_nohash_0.wav
# ./happy/f864cd4a_nohash_0.wav
# ./happy/f4c77b26_nohash_0.wav
# ./happy/92e17cc4_nohash_2.wav
# ./happy/bd061bef_nohash_0.wav
# ./happy/173ae793_nohash_0.wav
# ./happy/019fa366_nohash_0.wav
# ./happy/7de97453_nohash_0.wav
# ./happy/d4d898d7_nohash_2.wav
# ./happy/d7529c0c_nohash_0.wav
# ./happy/71f9bba8_nohash_1.wav
# ./happy/014f9f65_nohash_0.wav
# ./happy/a42a88ff_nohash_0.wav
# ./happy/91cdef62_nohash_0.wav
# ./happy/acde7e73_nohash_1.wav
# ./happy/76b58705_nohash_1.wav
# ./happy/c79159aa_nohash_0.wav
# ./happy/dc75148d_nohash_1.wav
# ./happy/0bde966a_nohash_0.wav
# ./happy/24befdb3_nohash_0.wav
# ./happy/f34e6f44_nohash_0.wav
# ./happy/89d6d11e_nohash_1.wav
# ./happy/b7669804_nohash_0.wav
# ./happy/f19c1390_nohash_0.wav
# ./happy/5628d7b7_nohash_2.wav
# ./happy/e652590d_nohash_0.wav
# ./happy/78030270_nohash_0.wav
# ./happy/37bd115d_nohash_2.wav
# ./happy/1aeef15e_nohash_0.wav
# ./happy/229978fd_nohash_0.wav
# ./happy/afb9e62e_nohash_0.wav
# ./happy/eee9b9e2_nohash_2.wav
# ./happy/2e0d80f7_nohash_0.wav
# ./happy/e102119e_nohash_0.wav
# ./happy/39dce8cc_nohash_0.wav
# ./happy/76424fa5_nohash_2.wav
# ./happy/8ec6dab6_nohash_0.wav
# ./happy/1625acd8_nohash_3.wav
# ./happy/18a1aab9_nohash_0.wav
# ./happy/4f256313_nohash_1.wav
# ./happy/fb24c826_nohash_0.wav
# ./happy/a0f93943_nohash_0.wav
# ./happy/99a9b015_nohash_0.wav
# ./happy/079dfce3_nohash_1.wav
# ./happy/32a19ecf_nohash_0.wav
# ./happy/b97c9f77_nohash_0.wav
# ./happy/25132942_nohash_0.wav
# ./happy/8a5acefd_nohash_1.wav
# ./happy/3fb8c268_nohash_1.wav
# ./happy/f8ad3941_nohash_0.wav
# ./happy/01d22d03_nohash_0.wav

# %%
#@title Split training e testing set
def move_files(src_folder, to_folder, list_file):
    with open(list_file) as f:
        for line in f.readlines():
            line = line.rstrip()
            dirname = os.path.dirname(line)
            dest = os.path.join(to_folder, dirname)
            if not os.path.exists(dest):
                os.mkdir(dest)
            shutil.move(os.path.join(src_folder, line), dest)


audio_folder = os.path.join('data/', 'audio')
validation_path = os.path.join(audio_folder, 'validation_list.txt')
test_path = os.path.join(audio_folder, 'testing_list.txt')

valid_folder = os.path.join('data/', 'valid')
test_folder = os.path.join('data/', 'test')
train_folder = os.path.join('data/', 'train')
os.mkdir(valid_folder)
os.mkdir(test_folder)

move_files(audio_folder, test_folder, test_path)
move_files(audio_folder, valid_folder, validation_path)
os.rename(audio_folder, train_folder)

# %%
#@title Remove validation set
# !cp -R data/valid/* data/test/
# !rm -rf data/valid/

# %%
#@title Manage dataset in Py
CLASSES = 'unknown, silence, yes, no, up, down, left, right, on, off, stop, go'.split(', ')


class SpeechCommandsDataset(Dataset):
    """Google speech commands dataset. Only 'yes', 'no', 'up', 'down', 'left',
    'right', 'on', 'off', 'stop' and 'go' are treated as known classes.
    All other classes are used as 'unknown' samples.
    See for more information: https://www.kaggle.com/c/tensorflow-speech-recognition-challenge
    """

    def __init__(self, folder, transform=None, classes=CLASSES, silence_percentage=0.1):
        all_classes = [d for d in os.listdir(folder) if os.path.isdir(os.path.join(folder, d)) and not d.startswith('_')]
        #for c in classes[2:]:
        #    assert c in all_classes

        class_to_idx = {classes[i]: i for i in range(len(classes))}
        for c in all_classes:
            if c not in class_to_idx:
                class_to_idx[c] = 0

        data = []
        for c in all_classes:
            d = os.path.join(folder, c)
            target = class_to_idx[c]
            for f in os.listdir(d):
                path = os.path.join(d, f)
                data.append((path, target))

        # add silence
        target = class_to_idx['silence']
        data += [('', target)] * int(len(data) * silence_percentage)

        self.classes = classes
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        path, target = self.data[index]
        data = {'path': path, 'target': target}

        if self.transform is not None:
            data = self.transform(data)

        return data

    def make_weights_for_balanced_classes(self):
        """adopted from https://discuss.pytorch.org/t/balanced-sampling-between-classes-with-torchvision-dataloader/2703/3"""

        nclasses = len(self.classes)
        count = np.zeros(nclasses)
        for item in self.data:
            count[item[1]] += 1

        N = float(sum(count))
        weight_per_class = N / count
        weight = np.zeros(len(self))
        for idx, item in enumerate(self.data):
            weight[idx] = weight_per_class[item[1]]
        return weight


class BackgroundNoiseDataset(Dataset):
    """Dataset for silence / background noise."""

    def __init__(self, folder, transform=None, sample_rate=16000, sample_length=1):
        audio_files = [d for d in os.listdir(folder) if os.path.isfile(os.path.join(folder, d)) and d.endswith('.wav')]
        samples = []
        for f in audio_files:
            path = os.path.join(folder, f)
            s, sr = librosa.load(path, sample_rate)
            samples.append(s)

        samples = np.hstack(samples)
        c = int(sample_rate * sample_length)
        r = len(samples) // c
        self.samples = samples[:r*c].reshape(-1, c)
        self.sample_rate = sample_rate
        self.classes = CLASSES
        self.transform = transform
        self.path = folder

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, index):
        data = {'samples': self.samples[index], 'sample_rate': self.sample_rate, 'target': 1, 'path': self.path}

        if self.transform is not None:
            data = self.transform(data)

        return data

# %% [markdown]
# ### Preprocess data

# %%
#@title
def should_apply_transform(prob=0.5):
    """Transforms are only randomly applied with the given probability."""
    return random.random() < prob


class LoadAudio(object):
    """Loads an audio into a numpy array."""

    def __init__(self, sample_rate=16000):
        self.sample_rate = sample_rate

    def __call__(self, data):
        path = data['path']
        if path:
            samples, sample_rate = librosa.load(path, self.sample_rate)
        else:
            # silence
            sample_rate = self.sample_rate
            samples = np.zeros(sample_rate, dtype=np.float32)
        data['samples'] = samples
        data['sample_rate'] = sample_rate
        return data


class FixAudioLength(object):
    """Either pads or truncates an audio into a fixed length."""

    def __init__(self, time=1):
        self.time = time

    def __call__(self, data):
        samples = data['samples']
        sample_rate = data['sample_rate']
        length = int(self.time * sample_rate)
        if length < len(samples):
            data['samples'] = samples[:length]
        elif length > len(samples):
            data['samples'] = np.pad(samples, (0, length - len(samples)), "constant")
        return data


class ChangeAmplitude(object):
    """Changes amplitude of an audio randomly."""

    def __init__(self, amplitude_range=(0.7, 1.1)):
        self.amplitude_range = amplitude_range

    def __call__(self, data):
        if not should_apply_transform():
            return data

        data['samples'] = data['samples'] * random.uniform(*self.amplitude_range)
        return data


class ChangeSpeedAndPitchAudio(object):
    """Change the speed of an audio. This transform also changes the pitch of the audio."""

    def __init__(self, max_scale=0.2):
        self.max_scale = max_scale

    def __call__(self, data):
        if not should_apply_transform():
            return data

        samples = data['samples']
        sample_rate = data['sample_rate']
        scale = random.uniform(-self.max_scale, self.max_scale)
        speed_fac = 1.0  / (1 + scale)
        data['samples'] = np.interp(np.arange(0, len(samples), speed_fac), np.arange(0,len(samples)), samples).astype(np.float32)
        return data


class StretchAudio(object):
    """Stretches an audio randomly."""

    def __init__(self, max_scale=0.2):
        self.max_scale = max_scale

    def __call__(self, data):
        if not should_apply_transform():
            return data

        scale = random.uniform(-self.max_scale, self.max_scale)
        data['samples'] = librosa.effects.time_stretch(data['samples'], 1+scale)
        return data


class TimeshiftAudio(object):
    """Shifts an audio randomly."""

    def __init__(self, max_shift_seconds=0.2):
        self.max_shift_seconds = max_shift_seconds

    def __call__(self, data):
        if not should_apply_transform():
            return data

        samples = data['samples']
        sample_rate = data['sample_rate']
        max_shift = (sample_rate * self.max_shift_seconds)
        shift = random.randint(-max_shift, max_shift)
        a = -min(0, shift)
        b = max(0, shift)
        samples = np.pad(samples, (a, b), "constant")
        data['samples'] = samples[:len(samples) - a] if a else samples[b:]
        return data


class AddBackgroundNoise(Dataset):
    """Adds a random background noise."""

    def __init__(self, bg_dataset, max_percentage=0.45):
        self.bg_dataset = bg_dataset
        self.max_percentage = max_percentage

    def __call__(self, data):
        if not should_apply_transform():
            return data

        samples = data['samples']
        noise = random.choice(self.bg_dataset)['samples']
        percentage = random.uniform(0, self.max_percentage)
        data['samples'] = samples * (1 - percentage) + noise * percentage
        return data


class ToMelSpectrogram(object):
    """Creates the mel spectrogram from an audio. The result is a 32x32 matrix."""

    def __init__(self, n_mels=32):
        self.n_mels = n_mels

    def __call__(self, data):
        samples = data['samples']
        sample_rate = data['sample_rate']
        s = librosa.feature.melspectrogram(samples, sr=sample_rate, n_mels=self.n_mels)
        data['mel_spectrogram'] = librosa.power_to_db(s, ref=np.max)
        return data


class ToTensor(object):
    """Converts into a tensor."""

    def __init__(self, np_name, tensor_name, normalize=None):
        self.np_name = np_name
        self.tensor_name = tensor_name
        self.normalize = normalize

    def __call__(self, data):
        tensor = torch.FloatTensor(data[self.np_name])
        if self.normalize is not None:
            mean, std = self.normalize
            tensor -= mean
            tensor /= std
        data[self.tensor_name] = tensor
        return data

# %%
#@title
class ToSTFT(object):
    """Applies on an audio the short time fourier transform."""

    def __init__(self, n_fft=2048, hop_length=512):
        self.n_fft = n_fft
        self.hop_length = hop_length

    def __call__(self, data):
        samples = data['samples']
        sample_rate = data['sample_rate']
        data['n_fft'] = self.n_fft
        data['hop_length'] = self.hop_length
        data['stft'] = librosa.stft(samples, n_fft=self.n_fft, hop_length=self.hop_length)
        data['stft_shape'] = data['stft'].shape
        return data


class StretchAudioOnSTFT(object):
    """Stretches an audio on the frequency domain."""

    def __init__(self, max_scale=0.2):
        self.max_scale = max_scale

    def __call__(self, data):
        if not should_apply_transform():
            return data

        stft = data['stft']
        sample_rate = data['sample_rate']
        hop_length = data['hop_length']
        scale = random.uniform(-self.max_scale, self.max_scale)
        stft_stretch = librosa.core.phase_vocoder(stft, 1+scale, hop_length=hop_length)
        data['stft'] = stft_stretch
        return data


class TimeshiftAudioOnSTFT(object):
    """A simple timeshift on the frequency domain without multiplying with exp."""

    def __init__(self, max_shift=8):
        self.max_shift = max_shift

    def __call__(self, data):
        if not should_apply_transform():
            return data

        stft = data['stft']
        shift = random.randint(-self.max_shift, self.max_shift)
        a = -min(0, shift)
        b = max(0, shift)
        stft = np.pad(stft, ((0, 0), (a, b)), "constant")
        if a == 0:
            stft = stft[:,b:]
        else:
            stft = stft[:,0:-a]
        data['stft'] = stft
        return data


class AddBackgroundNoiseOnSTFT(Dataset):
    """Adds a random background noise on the frequency domain."""

    def __init__(self, bg_dataset, max_percentage=0.45):
        self.bg_dataset = bg_dataset
        self.max_percentage = max_percentage

    def __call__(self, data):
        if not should_apply_transform():
            return data

        noise = random.choice(self.bg_dataset)['stft']
        percentage = random.uniform(0, self.max_percentage)
        data['stft'] = data['stft'] * (1 - percentage) + noise * percentage
        return data


class FixSTFTDimension(object):
    """Either pads or truncates in the time axis on the frequency domain, applied after stretching, time shifting etc."""

    def __call__(self, data):
        stft = data['stft']
        t_len = stft.shape[1]
        orig_t_len = data['stft_shape'][1]
        if t_len > orig_t_len:
            stft = stft[:,0:orig_t_len]
        elif t_len < orig_t_len:
            stft = np.pad(stft, ((0, 0), (0, orig_t_len-t_len)), "constant")

        data['stft'] = stft
        return data


class ToMelSpectrogramFromSTFT(object):
    """Creates the mel spectrogram from the short time fourier transform of a file. The result is a 32x32 matrix."""

    def __init__(self, n_mels=32):
        self.n_mels = n_mels

    def __call__(self, data):
        stft = data['stft']
        sample_rate = data['sample_rate']
        n_fft = data['n_fft']
        mel_basis = librosa.filters.mel(sample_rate, n_fft, self.n_mels)
        s = np.dot(mel_basis, np.abs(stft)**2.0)
        data['mel_spectrogram'] = librosa.power_to_db(s, ref=np.max)
        return data


class DeleteSTFT(object):
    """Pytorch doesn't like complex numbers, use this transform to remove STFT after computing the mel spectrogram."""

    def __call__(self, data):
        del data['stft']
        return data


class AudioFromSTFT(object):
    """Inverse short time fourier transform."""

    def __call__(self, data):
        stft = data['stft']
        data['istft_samples'] = librosa.core.istft(stft, dtype=data['samples'].dtype)
        return data

# %%
#@title
def get_data(batch_size, root, use_gpu=True):

    data_aug_transform = Compose([ChangeAmplitude(), ChangeSpeedAndPitchAudio(), FixAudioLength(), ToSTFT(),
                                  StretchAudioOnSTFT(), TimeshiftAudioOnSTFT(), FixSTFTDimension()])
    bg_dataset = BackgroundNoiseDataset(root + "train/_background_noise_", data_aug_transform)
    add_bg_noise = AddBackgroundNoiseOnSTFT(bg_dataset)

    train_feature_transform = Compose([ToMelSpectrogramFromSTFT(n_mels=40), DeleteSTFT(),
                                       ToTensor('mel_spectrogram', 'input')])
    train_dataset = SpeechCommandsDataset(root + "train",
                                          Compose([LoadAudio(), data_aug_transform,
                                                   add_bg_noise, train_feature_transform]))

    valid_feature_transform = Compose([ToMelSpectrogram(n_mels=40), ToTensor('mel_spectrogram', 'input')])
    valid_dataset = SpeechCommandsDataset(root + "test",
                                          Compose([LoadAudio(), FixAudioLength(), valid_feature_transform]))

    weights = train_dataset.make_weights_for_balanced_classes()
    sampler = WeightedRandomSampler(weights, len(weights))
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler,
                                  pin_memory=use_gpu, num_workers=2)
    valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False,
                                  pin_memory=use_gpu, num_workers=2)

    return train_dataloader, valid_dataloader

# %% [markdown]
# ### Build ShuffleNetV2

# %%
#@title
def initialize_net(model_path=''):
    net = shufflenet_v2_x0_5(num_classes=len(CLASSES), quantize=False)
    net.conv1[0] = nn.Conv2d(1, 24, 3, 2, 1, bias=False)

    if Path(model_path).exists():
      state_dict = torch.load(model_path)
      net.load_state_dict(state_dict, strict=False)

    return net

# %% [markdown]
# ### Train

# %%
#@title
def get_optimizer(model, lr, wd, momentum):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=wd)
    return optimizer

  
def get_cost_function():
    cost_function = torch.nn.CrossEntropyLoss()
    return cost_function


def train(net, data_loader, optimizer, cost_function, device='cuda:0'):
    samples = 0.
    cumulative_loss = 0.
    cumulative_accuracy = 0.

    net.train()  # Strictly needed if network contains layers which has different behaviours between train and test

    pbar = tqdm(data_loader, unit="audios", unit_scale=data_loader.batch_size, position=0, leave=True)
    for batch in pbar:
        inputs = batch['input']
        inputs = torch.unsqueeze(inputs, 1)
        targets = batch['target']

        # Load data into GPU
        inputs = inputs.to(device)
        targets = targets.to(device)

        # Forward pass
        outputs = net(inputs)

        # Apply the loss
        loss = cost_function(outputs, targets)

        # Reset the optimizer

        # Backward pass
        loss.backward()

        # Update parameters
        optimizer.step()

        optimizer.zero_grad()

        # Better print something, no?
        samples += inputs.shape[0]
        cumulative_loss += loss.item()
        _, predicted = outputs.max(1)
        cumulative_accuracy += predicted.eq(targets).sum().item()

        # Free cuda memory
        torch.cuda.empty_cache()

    return cumulative_loss/samples, cumulative_accuracy/samples*100

# %% [markdown]
# ### Test

# %%
#@title
def test(net, data_loader, cost_function, device='cuda:0', num_batches=0):
    samples = 0.
    cumulative_loss = 0.
    cumulative_accuracy = 0.

    net.eval()  # Strictly needed if network contains layers which has different behaviours between train and test
    done_batches = 0

    with torch.no_grad():
        pbar = tqdm(data_loader, unit="audios", unit_scale=data_loader.batch_size, position=0, leave=True)
        for batch in pbar:
            inputs = batch['input']
            inputs = torch.unsqueeze(inputs, 1)
            targets = batch['target']

            # Load data into GPU
            inputs = inputs.to(device)
            targets = targets.to(device)

            # Forward pass
            outputs = net(inputs)

            # Apply the loss
            loss = cost_function(outputs, targets)
            done_batches += 1

            # Better print something
            samples += inputs.shape[0]
            cumulative_loss += loss.item()  # Note: the .item() is needed to extract scalars from tensors
            _, predicted = outputs.max(1)
            cumulative_accuracy += predicted.eq(targets).sum().item()

            # Free cuda memory
            torch.cuda.empty_cache()

            if  0 < num_batches <= done_batches:
                return cumulative_loss/samples, cumulative_accuracy/samples*100

    return cumulative_loss/samples, cumulative_accuracy/samples*100

# %% [markdown]
# ### Predict

# %%
#@title
def predict(input_path, net, use_gpu=True):
    print("Predicting " + input_path + "...")
    device = 'cuda:0' if use_gpu else 'cpu'

    feature_transform = Compose([ToMelSpectrogram(n_mels=40), ToTensor('mel_spectrogram', 'input')])
    transform = Compose([LoadAudio(), FixAudioLength(), feature_transform])

    audio = transform({'path': input_path})
    audio_loader = DataLoader(audio, batch_size=1, shuffle=False,
                              pin_memory=use_gpu, num_workers=2)

    net.eval()  # Strictly needed if network contains layers which has different behaviours between train and test

    audio = audio_loader.dataset['input']
    audio = torch.unsqueeze(audio, 1)
    audio = audio.view(1, 1, 40, 32)

    # Load data into GPU
    audio = audio.to(device)

    # Forward into network
    output = net.forward(audio)
    class_index = output.data.max(1, keepdim=True)[1]

    torch.cuda.empty_cache()
    return CLASSES[class_index]

# %% [markdown]
# ### Main

# %%
#@title
def main(batch_size=128, 
         use_gpu=True,
         learning_rate=0.001, 
         weight_decay=0.000001, 
         momentum=0.9, 
         epochs=50,
         root="data/",
         save=True,
         perform_training=True):

    device = 'cuda:0' if use_gpu else 'cpu'
    torch.cuda.empty_cache

    model_path = 'model/weights_mn_2.pth'

    net = initialize_net(model_path=model_path).to(device)

    # Op Counter
    net.eval()
    net.to(device)
    dsize = (32, 1, 40, 32)
    r_input = torch.randn(dsize).to(device)
    macs, params = profile(net, inputs=(r_input,), verbose=False)
    print("\n%s\t| %s" % ("Params(M)", "FLOPs(G)"))
    print("%.2f\t\t| %.2f" % (params / (1000 ** 2), macs / (1000 ** 3)))
    print()

    if not perform_training:
        # print(root)
        input_audios = [predict(input_path=os.path.join(root, r), net=net, use_gpu=use_gpu) for r in os.listdir(root)]
        print(input_audios)
        return
    else:
        if root is '':
            print("You need to specify the dataset path")
            return
        train_loader, test_loader = get_data(batch_size=batch_size,
                                             root=root, use_gpu=use_gpu)

        print("{")
        optimizer = get_optimizer(net, learning_rate, weight_decay, momentum)

        cost_function = get_cost_function()

        # train_loss, train_accuracy = test(net, train_loader, cost_function, device)
        # test_loss, test_accuracy = test(net, test_loader, cost_function, device)
        # print('\nTest before training')
        # print('\t{"Training loss": %.5f, "Training accuracy": %.2f},' % (train_loss, train_accuracy))
        # print('\t{"Test loss": %.5f, "Test accuracy": %.2f},' % (test_loss, test_accuracy))
        # print('-----------------------------------------------------')

        train_loss_curve = []
        train_accuracy_curve = []
        test_loss_curve = []
        test_accuracy_curve = []

        print('\t"training": [')

        for e in range(epochs):
            train_loss, train_accuracy = train(net, train_loader, optimizer, cost_function, device)
            test_loss, test_accuracy = test(net, test_loader, cost_function, device)
            print('\n\t\tEpoch: {:d}'.format(e+1))
            print('\t\t\t{"Training loss": %.5f, "Training accuracy": %.2f},' % (train_loss, train_accuracy))
            print('\t\t\t{"Test loss": %.5f, "Test accuracy": %.2f},' % (test_loss, test_accuracy))
            # print('-----------------------------------------------------')

            train_loss_curve.append(train_loss)
            train_accuracy_curve.append(train_accuracy)
            test_loss_curve.append(test_loss)
            test_accuracy_curve.append(test_accuracy)

            # saving model
            if save:
                print("Saving weights")
                torch.save(net.state_dict(), model_path)

        # train_loss, train_accuracy = test(net, train_loader, cost_function, device)
        # test_loss, test_accuracy = test(net, test_loader, cost_function, device)
        # print('\n\t\tTest after training')
        # print('\t\t{"Training loss": %.5f, "Training accuracy": %.2f},' % (train_loss, train_accuracy))
        # print('\t\t{"Test loss": %.5f, "Test accuracy": %.2f}' % (test_loss, test_accuracy))
        # print('-----------------------------------------------------')

        print('\t],')

# %% [markdown]
# ### Execution

# %%
#@title Add a input
# !mkdir -p data/input/
# !cp data/test/go/022cd682_nohash_0.wav data/input/

# %%
#@title Run 10 training epochs
main(root='data/', epochs=1, batch_size=32, perform_training=True,
         save=True, use_gpu=True)

# %%
#@title Run input
main(root='data/input/', perform_training=False, save=False,
          use_gpu=True)
# Out:
# Params(M)	| FLOPs(G)
# 0.06		| 0.02
#
# Predicting data/input/022cd682_nohash_0.wav...
# ['go']

# %% [markdown]
# ##Export models

# %%
#@title Load high weights from drive
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/My Drive/Colab Notebooks/weights_shufflenet_v2_05.pth" model/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def quantize_model(model, backend):
    _dummy_input_data = torch.rand(32, 1, 40, 32)
    if backend not in torch.backends.quantized.supported_engines:
        raise RuntimeError("Quantized backend not supported ")
    torch.backends.quantized.engine = backend
    model.eval()
    
    # Make sure that weight qconfig matches that of the serialized models
    my_qconfig = torch.quantization.QConfig(activation=torch.quantization.MinMaxObserver.with_args(dtype=torch.quint8),
                           weight=torch.quantization.default_observer.with_args(dtype=torch.qint8))
    if backend == 'fbgemm':
        model.qconfig = torch.quantization.QConfig(
            activation=torch.quantization.default_observer,
            weight=torch.quantization.default_per_channel_weight_observer)
    elif backend == 'qnnpack':
        model.qconfig = my_qconfig

    model.fuse_model()
    torch.quantization.prepare(model, inplace=True)
    
    # Calibrate with the training set
    batch_size = 32
    num_batches = 10
    print('Calibration in progress. Total batches: ' + str(batch_size * num_batches))
    cost_function = get_cost_function()
    train_loader, test_loader = get_data(batch_size=batch_size,
                                          root='data/', use_gpu=False)
    test_loss, test_accuracy = test(model, train_loader, cost_function, 'cpu', num_batches=num_batches)
    print()
    print('Test loss: %.5f, Test accuracy: %.2f' % (test_loss, test_accuracy))

    torch.quantization.convert(model, inplace=True)

    return

def get_net(import_model_path, quantize=False):
    empty_net = shufflenet_v2_x0_5(num_classes=len(CLASSES), quantize=False)
    empty_net.conv1[0] = nn.Conv2d(1, 24, 3, 2, 1, bias=False)

    if Path(import_model_path).exists():
        net = empty_net
        
        if quantize:
            backend = 'qnnpack'
            state_dict = torch.load(import_model_path, map_location=lambda storage, loc: storage)
            net.load_state_dict(state_dict, strict=False)
            quantize_model(model=net, backend=backend)
        else:
            state_dict = torch.load(import_model_path, map_location=lambda storage, loc: storage)
            net.load_state_dict(state_dict, strict=False)       
    else:
        raise Exception("File to import does not exists.")
    
    return net


def export_model(input_path, quantize=False):
    import_model_path = 'model/weights_shufflenet_v2_05.pth'
    export_model_path = 'model/mobile_shufflenet_v2_05.pt'
    
    dsize = (1, 1, 40, 32)

    feature_transform = Compose([ToMelSpectrogram(n_mels=40), ToTensor('mel_spectrogram', 'input')])
    transform = Compose([LoadAudio(), FixAudioLength(), feature_transform])

    audio = transform({'path': input_path})
    audio_loader = DataLoader(audio, batch_size=1, shuffle=False,
                              pin_memory=False, num_workers=2)
    audio = audio_loader.dataset['input']
    audio = torch.unsqueeze(audio, 1)
    audio = audio.view(dsize)

    net = get_net(import_model_path=import_model_path, quantize=False).to(torch.device("cpu"))
    net.cpu()
    net.eval()

    if quantize:
        # saving quantized version
        quantized_net = get_net(import_model_path=import_model_path, quantize=True).to(torch.device("cpu"))
        # quantized_model_path = import_model_path.split('.')[0] + '_quantized.pth'
        # torch.jit.save(torch.jit.script(quantized_net), quantized_model_path)
        # print("Saving quantized weights in " + quantized_model_path)

        # Test
        num_batches = 5
        batch_size = 32
        print('Test on ' + str(batch_size * num_batches) + ' samples')
        cost_function = get_cost_function()
        train_loader, test_loader = get_data(batch_size=batch_size,
                                              root='data/', use_gpu=False)
        test_loss, test_accuracy = test(quantized_net, test_loader, cost_function, 'cpu', num_batches=num_batches)
        print()
        print('Test loss: %.5f, Test accuracy: %.2f' % (test_loss, test_accuracy))

        # saving quantized version for mobile
        traced_script_module = torch.jit.trace(quantized_net, audio, check_trace=False)
        export_quantized_model_path = export_model_path.split('.')[0] + '_quantized.pt'
        traced_script_module.save(export_quantized_model_path)
        print("Exporting quantized version in " + export_quantized_model_path)

    
    # saving not-quantized version for mobile
    traced_script_module = torch.jit.trace(net, audio)
    traced_script_module.save(export_model_path)
    print("Exporting model in " + export_model_path)

# %%
data = 'data/input/022cd682_nohash_0.wav'
quantize = True

export_model(input_path=data, quantize=quantize)
# Out:
# Calibration in progress. Total batches: 320
#   1%|          | 288/56224 [00:31<1:54:05,  8.17audios/s]
# Test loss: 0.03246, Test accuracy: 63.44
# Test on 160 samples
#   1%|          | 96/15008 [00:13<43:58,  5.65audios/s]
# Test loss: 0.02426, Test accuracy: 72.50
# Exporting quantized version in model/mobile_shufflenet_v2_05_quantized.pt
# Exporting model in model/mobile_shufflenet_v2_05.pt

# %%
#@title copy models into drive
# !cp model/mobile_shufflenet_v2_05.pt "/content/drive/My Drive/Colab Notebooks/"
# !cp model/mobile_shufflenet_v2_05_quantized.pt "/content/drive/My Drive/Colab Notebooks/"
